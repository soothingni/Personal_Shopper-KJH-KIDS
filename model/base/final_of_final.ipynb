# %%
import transfer

# %%
res_ver = "resnet101"
base, model = transfer.create_res_model(res_ver)  #create model

# %%
transfer.freeze_layer(base, 346)
# Out:
# traninable layers in ResNet: 0

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# anchor (InputLayer)             [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# positive (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# negative (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          44887552    anchor[0][0]
#                                                                  positive[0][0]
#                                                                  negative[0][0]
# ...

# %%
from tensorflow.keras.optimizers import Adam, SGD

# %%
model_weights_dir = './trained/resnet101_detectron_val/000330-1.3812-4.8970.h5'
model.load_weights(model_weights_dir)

# %%
model.compile(optimizer=Adam(learning_rate=0.0001, clipnorm=3.0),
                    loss=transfer.lossless_triplet_loss)

# %%
cnt = 0
for layer in base.layers[0].layers:
    print(layer.trainable == True)
    cnt += 1
print(cnt)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# ...
