# %%
import tensorflow as tf

from tensorflow.keras import backend as K
from tensorflow.keras.layers import Input, BatchNormalization, LSTM, Dense, concatenate, Conv2D, MaxPooling2D, Flatten, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.utils import plot_model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50

import numpy as np
import random
import matplotlib.pyplot as plt
import os
import cv2
import json

tf.__version__
# Out:
# '2.1.0'

# %% [markdown]
# # 1. Define loss & base network
# - 두 가지 loss 함수
#     - `triplet_loss`
#         - 출처: https://thelonenutblog.wordpress.com/2017/12/18/what-siamese-dreams-are-made-of/
#     - `lossless_triplet_loss`
#         - 출처: https://towardsdatascience.com/lossless-triplet-loss-7e932f990b24

# %%
def lossless_triplet_loss(y_true, y_pred, N=128, beta=128, epsilon=1e-8):
    """
    Implementation of the triplet loss function
    
    Arguments:
    y_true -- true labels, required when you define a loss in Keras, you don't need it in this function.
    y_pred -- python list containing three objects:
            anchor -- the encodings for the anchor data
            positive -- the encodings for the positive data (similar to anchor)
            negative -- the encodings for the negative data (different from anchor)
    N  --  The number of dimension 
    beta -- The scaling factor, N is recommended
    epsilon -- The Epsilon value to prevent ln(0)
    
    
    Returns:
    loss -- real number, value of the loss
    """
    anchor = tf.convert_to_tensor(y_pred[:,0:N])
    positive = tf.convert_to_tensor(y_pred[:,N:N*2]) 
    negative = tf.convert_to_tensor(y_pred[:,N*2:N*3])
    
    # distance between the anchor and the positive
    pos_dist = tf.reduce_sum(tf.square(tf.subtract(anchor,positive)),1)
    # distance between the anchor and the negative
    neg_dist = tf.reduce_sum(tf.square(tf.subtract(anchor,negative)),1)
    
    #Non Linear Values  
    
    # -ln(-x/N+1)
    pos_dist = -tf.math.log(-tf.divide((pos_dist),beta)+1+epsilon)
    neg_dist = -tf.math.log(-tf.divide((N-neg_dist),beta)+1+epsilon)
    
    # compute loss
    loss = neg_dist + pos_dist
    
    
    return loss

# %%
def res_base_network(in_dims, out_dims, activation='sigmoid'):
    model = Sequential()
    
    model.add(ResNet50(
    include_top=False, weights='imagenet', input_shape=in_dims, pooling='avg', classes=1000))

    model.add(Dense(1024, activation = 'relu'))
    model.add(Dense(out_dims, activation = activation))

    return model

# %% [markdown]
# # 2. Define input generator

# %%
train_data_dir = '../train'
val_data_dir = '../val'

# %%
os.listdir(train_data_dir)
# Out:
# ['(5598)Zippered_Faux_Leather_Joggers',
#  '(267)Asymmetrical_Open-Front_Blazer',
#  '(2166)Flat-Front_Skinny_Jeans',
#  '(1871)Elephant_Paisley_Print_Dress',
#  '(4096)Quilted_Dolphin_Shorts',
#  '(1052)Clean_Wash_Slim-Leg_Jeans',
#  '(1573)Denim_Daze_Ripped_Shorts',
#  '(1095)Collarless_Moto_Jacket',
#  '(32)Abstract_Chevron_Print_Shorts',
#  '(4495)Side-Slit_Maxi_Dress',
#  '(1587)Denim_Utility_Jumpsuit',
#  '(4231)Ripped_Skinny_Jeans',
#  '(4259)Rose_Print_Chiffon_Dress',
#  '(4329)Rugby_Stripe_Sweater',
#  '(409)Belted_Daisy_Print_Dress',
#  '(1131)Colorblock_Yoga_Shorts',
#  '(4178)Rhinestoned___Beaded_Blouse',
#  '(5347)Tweed_Boyfriend_Blazer',
#  '(781)Cascading_Layered_Shift_Dress',
#  '(802)Charlie_Brown_Print_Tank',
#  '(5307)Tropical_Print_Dress',
#  '(2435)French_Terry_Tee',
#  '(1428)Cropped_Trench_Coat',
#  '(1194)Contrast_Trim_Henley',
#  '(4944)Striped_Swim_Trunks',
#  '(4887)Striped_Linen_Ringer_Tee',
#  '(368)Beaded_Geo-Embroidered_Halter_Top',
#  '(254)Art_Nouveau_Floral_Print_Top',
#  '(4070)Polka_Dot_Woven_Shorts',
#  '(1462)Cuffed_Low-Rise_Denim_Shorts',
#  '(1169)Colored_Denim_Shorts',
#  '(4226)Ribbed_Turtleneck_Sweater',
#  '(4122)Raga_Geo_Stripe_Hooded_Cardigan',
#  '(4067)Polka_Dot_Swim_Trunks',
#  '(5312)Tropical_Print_Mini_Skirt',
#  '(3562)Minimal_Muse_V-Neck_Tee',
#  '(4034)Pleated_Wide-Leg_Culottes',
#  '(5313)Tropical_Print_Pocket_Tank',
#  '(193)Abstract_Surplice_Maxi_Dress',
#  '(4551)Slub_Knit_Cardigan',
#  '(4675)Space_Dye_Waist_Running_Shorts',
#  '(5102)Textured_Longline_Tee',
#  '(439)Belted_Trench_Coat',
#  '(5553)Woven_Shift_Dress',
#  '(1819)Drop-Sleeve_Heathered_Tee',
#  '(534)Boxy_Crepe_Romper',
#  '(141)Abstract_Print_Maxi_Skirt',
#  '(255)Astronaut_Print_Tank',
#  '(3794)Oversized_Fuzzy_Knit_Cardigan',
#  '(455)Bird_Print_Pocket_Tee',
#  '(1226)Creased-Front_Leggings',
#  '(5535)Woven_Bermuda_Shorts',
#  '(1956)Embroidered_Peasant_Tank',
#  '(675)Button-Down_Denim_Dress',
#  '(1199)Control_Sector_Reversible_Drawstring_Shorts',
#  '(1644)Distressed_Cloud_Wash_Cutoffs',
#  '(2707)High-Neck_Blouse',
#  '(4134)Raw-Edged_Distressed_Tank',
#  '(14)Abstract-Printed_Capri_Leggings',
#  '(2657)Heathered_Raglan_Tee',
#  '(2993)Lace_Cami_Jumpsuit',
#  '(438)Belted_Stripe_Print_Shorts',
#  '(186)Abstract_Stripe_Print_Jumpsuit',
#  '(1802)Drawstring_Hood_Shift_Dress',
#  '(985)Classic_Mom_Jeans',
#  '(5606)Zippered_Longline_Sweater',
#  '(5589)Zippered-Ankle_Skinny_Jeans',
#  '(3586)Mock_Neck_Floral_Dress',
#  '(4435)Shaggy_Popcorn_Knit_Sweater',
#  '(404)Belted_Crochet-Paneled_Dress',
#  '(2402)Fold-Over_Yoga_Shorts',
#  '(3410)Medallion_Print_Blouse',
#  '(1529)Dainty_Lace_Tee',
#  '(3896)Paris_Graphic_Dress',
#  '(1435)Crosshatch_Bodycon_Dress',
#  '(4510)Simba_Graphic_Hoodie',
#  '(4818)Striped_Bodycon_Skirt',
#  '(1048)Clean_Wash_High-Rise_Skinny_Jeans',
#  '(3870)Palm_Tree_Graphic_Tee',
#  '(1724)Dotted_Chambray_Babydoll_Dress',
#  '(2062)Faux_Gem_Woven_Cardigan',
#  '(3903)Patterned_Knit_Sweater',
#  '(3273)Malibu_Beach_Muscle_Tee',
#  '(3657)Notched_Open-Front_Textured_Blazer',
#  '(3534)Mineral_Wash_Cutoffs',
#  '(2299)Floral_Print_Crepe_Skirt',
#  '(339)Basquiat_Crown_Tee',
#  '(3825)Paisley_Floral_A-Line_Dress',
#  '(2887)Knit_Romper',
#  '(1363)Crochet_Denim_Cutoffs',
#  '(2881)Knit_Crew_Neck_Sweater',
#  '(4243)Romantic_Rose_Dress',
#  '(2201)Floral_Bow-Front_Shorts',
#  '(3125)Life_in_Progress_Distressed_Low-Rise_Skinny_Jeans',
#  '(183)Abstract_Stripe_Bodycon_Dress',
#  '(4422)Sequined_Chevron_Pattern_Shorts',
#  '(4324)Ruffled_Trim_Sweater',
#  '(3898)Paris_Graphic_Tee',
#  '(229)Acid_Wash_Distressed_Cutoffs',
#  '(1815)Dreamcatcher_Muscle_Tee',
#  '(1114)Colorblock_Cutout_Jumpsuit',
#  '(2055)Faux_Fur_Collared_Zippered_Coat',
#  '(2966)Lace-Paneled_Sweater',
#  '(2013)Eyelash_Lace_Pleated_Dress',
#  '(96)Abstract_Paisley_Print_Kimono',
#  '(5354)Twist-Back_Colorblocked_Dress',
#  '(5270)Tribal_Print_Maxi_Dress',
#  '(1238)Crepe_Shawl_Collar_Blazer',
#  '(1196)Contrast_Waist_Sweatpants',
#  '(954)Classic_Faded_Denim_Jacket',
#  '(5336)Tulle_Overlay_Cami_Dress',
#  '(3217)Longline_Striped_Cardigan',
#  '(1324)Crochet-Trimmed_Cami_Fit___Flare_Dress',
#  '(1467)Cuffed_Tee_Shirt_Dress',
#  '(1648)Distressed_Denim_Bermuda_Shorts',
#  '(298)Bandana_Print_Sweatshorts',
#  '(917)Classic_Baseball_Tee',
#  '(2128)Favorite_Capri_Leggings',
#  '(1031)Classic_Wash_-_Skinny_Jeans',
#  '(4545)Slouchy_Twill_Utility_Jacket',
#  '(5275)Tribal_Print_Pleated_Dress',
#  '(1564)Deep_V-Neck_Sweater',
#  '(662)Burnout_Pocket_Tee',
#  '(4)36_Plaid_Shirt_Dress',
#  '(4494)Side-Slit_Marled_Dress',
#  '(5429)Varsity_Dreamer_Graphic_Tee',
#  '(1695)Ditsy_Floral_Jersey_Dress',
#  '(2145)Femme_Fatale_Crochet_Dress',
#  '(919)Classic_Bootcut_Jeans',
#  '(4374)Scuba_Knit_Collared_Jacket',
#  '(1830)Duo-Stripe_Tee',
#  '(3145)Linen-Blend_Shorts',
#  '(266)Asymmetrical_Loose_Knit_Top',
#  '(1183)Contrast-Trimmed_Tank',
#  '(2362)Floral_Tribal_Print_Shorts',
#  '(1957)Embroidered_Pintucked_Blouse',
#  '(2732)High-Slit_Tartan_Plaid_Midi_Dress',
#  '(347)Be_True_Cutoff_Tee',
#  '(1192)Contrast_Mesh_Pencil_Skirt',
#  '(758)Camera_Grid_Muscle_Tee',
#  '(2289)Floral_Print_Babydoll_Dress',
#  '(5456)Voila_Graphic_Muscle_Tee',
#  '(497)Botanical_Print_Shift_Dress',
#  '(1498)Cutout_Bandage_Dress',
#  '(5126)Textured_Zigzag_Bodycon_Dress',
#  '(1531)Daisy_Cap-Sleeved_Dress',
#  '(1762)Draped_Knit_Cardigan',
#  '(1187)Contrast_Drawstring_Denim_Shorts',
#  '(3441)Mesh-Paneled_T-Shirt_Dress',
#  '(338)Basic_V-Neck_Tee',
#  '(1918)Embroidered_Floral_Shift_Dress',
#  '(5568)Yoga_Capri_Leggings',
#  '(2542)Giraffe_Print_Sweater',
#  '(641)Brocade_Floral_Peplum_Top',
#  '(683)Button-Front_Pocket_Skirt',
#  '(4120)Raga_Floral_Crochet-Paneled_Dress',
#  '(5189)Time_To_Shine_Tee',
#  '(1582)Denim_Pencil_Skirt',
#  '(4137)Really_Smart_Striped_Ringer_Tee',
#  '(667)But_Not_Really_Muscle_Tee',
#  '(3840)Paisley_Print_Fit___Flare_Dress',
#  '(5373)Unstructured_Cargo_Shorts',
#  '(1873)Elephant_Print_Drawstring_Shorts',
#  '(3741)Organza-Paneled_Dress',
#  '(250)Antiqued_Floral_Denim_Shorts',
#  '(5128)The_Beatles_Graphic_Tank',
#  '(283)BRB_Graphic_Tee',
#  '(3936)Pintucked_Chiffon_Blouse',
#  '(4419)Sequined_Abstract_Pattern_Dress',
#  '(1803)Drawstring_Joggers',
#  '(2434)French_Terry_Sweatshorts',
#  '(4234)Road_Trip_Ready_Cardigan',
#  '(3353)Marled_Midi_Turtleneck_Dress',
#  '(4732)Strapless_Drawstring_Romper',
#  '(1612)Diamond_Embroidered_Shorts',
#  '(4844)Striped_Cutout-Back_Tank',
#  '(900)Civil_Longline_Mesh_Tee',
#  '(2258)Floral_Lace_Fit___Flare_Dress',
#  '(3771)Ornate_Paisley_Maxi_Skirt',
#  '(5325)Trust_Nobody_Muscle_Tee',
#  '(729)Cable_Knit_Cardigan',
#  '(4959)Striped_Turtle_Neck_Dress',
#  '(367)Beaded_Flowy_Cotton_Dress',
#  '(3052)Layered-Panel_Chiffon_Blouse',
#  '(5278)Tribal_Print_Romper',
#  '(713)Buttoned_Lace_Panel_Top',
#  '(2872)Knife-Pleated_Denim_Shorts',
#  '(910)Clashist_Aluminum_Foil_Print_Tee',
#  '(4967)Striped_Waffle_Knit_Sweater',
#  '(3433)Mesh-Paneled_Heathered_Performance_Tank',
#  '(86)Abstract_Mosaic_Racerback_Dress',
#  '(3504)Mickey_Mouse_Distressed_Muscle_Tee',
#  '(2053)Faux_Fur_Collar_Coat',
#  '(5344)Turtleneck_Sweater_Dress',
#  '(4929)Striped_Shift_Drawstring_Dress',
#  '(3813)Paint_Splatter_Tank',
#  '(5502)West_Coast_Mesh_Jersey',
#  '(493)Botanical_Floral_Cutout_Romper',
#  '(1115)Colorblock_Heathered_Capri_Leggings',
#  '(112)Abstract_Print_Buttoned_Romper',
#  '(3679)Ombr_eacute__Tank',
#  '(3932)Pintuck_Pleated_Blouse',
#  '(4292)Rose_Print_Sweatshorts',
#  '(836)Chiffon-Layered_Top',
#  '(2924)LEEF_PARIS_Abstract_Geo_Print_Shorts',
#  '(832)Chic_High-Waisted_Jeggings',
#  '(167)Abstract_Print_Twist-Back_Blouse',
#  '(647)Brooklyn_Nets_Logo_Hoodie',
#  '(925)Classic_Cardigan',
#  '(2454)Fringed_Shawl_Collar_Cardigan',
#  '(1693)Ditsy_Floral_Babydoll_Dress',
#  '(4048)Polka_Dot_Baseball_Tee',
#  '(2936)Lace-Edged_Cami_Romper',
#  '(94)Abstract_Paisley_Fit___Flare_Dress',
#  '(2405)Folk_Print_Fit___Flare_Dress',
#  '(3012)Lace_Paneled_Tee',
#  '(5438)Velveteen_Damask-Patterned_Leggings',
#  '(3515)Mid-Rise_-_Acid_Wash_Jeggings',
#  '(1646)Distressed_Cropped_Jeans',
#  '(2144)Felix_the_Cat_Muscle_Tee',
#  '(5443)Velveteen_Surplice_Dress',
#  '(4858)Striped_Fold-Over_Maxi_Skirt',
#  '(4656)Southwestern_Print_Maxi_Skirt',
#  '(4309)Ruffled-Sleeve_Layered_Blouse',
#  '(3910)Perforated_Athletic_Tank',
#  '(177)Abstract_Skort_Romper',
#  '(4045)Pointelle_Knit_Crop_Tank',
#  '(1253)Crinkled_Asymmetrical_Kimono',
#  '(4115)Racerback_Floral_A-Line_Dress',
#  '(2096)Faux_Leather_Panel_Hoodie',
#  '(4578)Smocked_Drawstring_Shorts',
#  '(1785)Drawstring_Camo_Shorts',
#  '(3112)Life_In_Progress_Wrap_Belt_Chambray_Dress',
#  '(5029)Tassel-Trimmed_Shorts',
#  '(5420)Varsity-Striped_Piqu_eacute__Track_Jacket',
#  '(2377)Flounced_Floral_Dress',
#  '(3265)M-Slit_Knit_Maxi_Skirt',
#  '(4022)Pleated_Peasant_Blouse',
#  '(1741)Double-Breasted_Blazer',
#  '(3589)Mock_Neck_Tee',
#  '(3776)Ornate_Print_Shorts',
#  '(5184)Tile_Print_Fit___Flare_Dress',
#  '(2507)Geo_Pattern_Bodycon_Dress',
#  '(4152)Reason_Woke_Up_Like_This_Tee',
#  '(4127)Raglan_Sleeve_Tee',
#  '(3544)Mineral_Wash_Drawstring_Sweatpants',
#  '(573)Boxy_Medallion_Print_Top',
#  '(25)Abstract_Brushstroke_Print_Pencil_Skirt',
#  '(1576)Denim_Drawstring_Jumpsuit',
#  '(4614)Southwestern-Inspired_Knit_Leggings',
#  '(248)Animal_Print_Satin_Blouse',
#  '(204)Abstract_Tribal_Print_Halter_Jumpsuit',
#  '(1868)Elegant_Crochet_Lace_Dress',
#  '(1453)Cuffed_Drawstring_Shorts',
#  '(4080)Posh_Tube_Dress',
#  '(4671)Southwestern_Stripe_Print_Dress',
#  '(2315)Floral_Print_Mesh_Dress',
#  '(4312)Ruffled_Floral_Blouse',
#  '(1416)Cropped_Crew_Neck_Tee',
#  '(4031)Pleated_Square_Neck_Dress',
#  '(4279)Rose_Print_Mini_Skirt',
#  '(153)Abstract_Print_Ruffled_Romper',
#  '(3318)Marled_Knit_Combo_Jacket',
#  '(5582)Zip_Collar_Bomber',
#  '(5012)Swiss_Dot_Crochet_Tank',
#  '(754)California_Graphic_Crop_Top',
#  '(4492)Side-Slit_Knit_Sweater',
#  '(2518)Geo_Print_Romper',
#  '(1459)Cuffed_Lined-Blend_Shorts',
#  '(942)Classic_Denim_Blazer',
#  '(853)Chiffon-Trimmed_Jumpsuit',
#  '(2459)Frond_Print_Mesh_Tee',
#  '(4386)Scuba_Knit_Sphinx_Graphic_Tee',
#  '(5009)Sweet_Crochet_Blouse',
#  '(3567)Mixed_Floral_Ruffle-Sleeve_Maxi_Dress',
#  '(5051)Texture-Panel_Heathered_Shorts',
#  '(16)Abstract-Stripe_Fuzzy_Sweater',
#  '(1778)Drapey_Marled_Knit_Cardigan',
#  '(3276)Mandala_Print_Maxi_Dress',
#  '(5116)Textured_Stripe_A-Line_Dress',
#  '(2839)Island_Graphic_Boxy_Tee',
#  '(5250)Tribal_Print_Cutout_Back_Dress',
#  '(5215)Triangle_Print_Chiffon_Blouse',
#  '(3386)Married_To_The_Mob_Fun_Tank',
#  '(2563)Grunge_Bleached_Denim_Cutoffs',
#  '(2044)Faux-Fur_Trimmed_Puffer_Parka',
#  '(633)Braided_Crew_Neck_Sweater',
#  '(2502)Geo_Halter_Maxi_Dress',
#  '(993)Classic_Pleated_Shorts',
#  '(2074)Faux_Leather___Tulle_Combo_Dress',
#  '(1067)Coated_Clean_Wash_-_Skinny_Jeans',
#  '(4315)Ruffled_Floral_Print_Shorts',
#  '(2581)Heathered_Chiffon-Paneled_Tee',
#  '(4387)Scuba_Knit_Varsity_Jacket',
#  '(3280)Mandala_Print_Tee',
#  '(2266)Floral_Lace_Mini_Skirt',
#  '(2632)Heathered_Knit_Tank',
#  '(416)Belted_Lace_Print_Dress',
#  '(4801)Stripe_Slub_Knit_Tee',
#  '(1514)Cutout_Sunflower_Tank',
#  '(2578)Heathered_Baseball_Stripe_Tee',
#  '(2838)Inverted_Seam_Knit_Sweater',
#  '(1565)Def_Leppard_Burnout_Tank',
#  '(3492)Metallic_Sheer-Paneled_Sweater',
#  '(544)Boxy_Dolman_Sleeve_Top',
#  '(2767)Hola_LA_Muscle_Tee',
#  '(3964)Plaid_Shirt_Dress',
#  '(550)Boxy_Fancy_Graphic_Tee',
#  '(3980)Pleated_Button-Front_Jumpsuit',
#  '(737)Cacti_Print_Tee',
#  '(1535)Daisy_Graphic_Muscle_Tee',
#  '(2594)Heathered_Crossover-Waist_Shorts',
#  '(4948)Striped_Textured_Sweater',
#  '(18)Abstract-Trimmed_Knit_Tank',
#  '(1945)Embroidered_Mesh_Gauze_Blouse',
#  '(3547)Mineral_Wash_Hooded_Dress',
#  '(2165)Flat-Front_Shorts',
#  '(2688)Heathered_Waffle_Knit_Baseball_Tee',
#  '(1390)Crochet_Trim_Belted_Romper',
#  '(1877)Elephant_Print_Tee',
#  '(1874)Elephant_Print_Maxi_Dress',
#  '(2202)Floral_Brocade_A-Line_Dress',
#  '(4572)Slub_Knit_Tee',
#  '(2603)Heathered_Drawstring_Joggers',
#  '(4266)Rose_Print_Fit___Flare_Dress',
#  '(4885)Striped_Linen_Belted_Shorts',
#  '(874)Chiffon_Twist-Front_Top',
#  '(3188)Longline_Floral_Lace_Cardigan',
#  '(4923)Striped_Sateen_Pencil_Skirt',
#  '(2921)LA_NY_Graphic_Tee',
#  '(3000)Lace_Inset_Cami_Dress',
#  '(173)Abstract_Printed_Romper',
#  '(1887)Embroidered-Trim_Cami_Dress',
#  '(2370)Floral_Wrap-Front_Maxi_Skirt',
#  '(4108)Quilted_Sweater',
#  '(911)Clashist_Oil_Slick_Print_Leggings',
#  '(4921)Striped_Rose_Cami_Romper',
#  '(3529)Mineral_Wash_Athletic-Ribbed_Joggers',
#  '(4859)Striped_Fringe-Trim_Shawl_Cardigan',
#  '(2855)Kaleidoscopic_Floral_Dress',
#  '(1622)Diamond_Print_Halter_Maxi_Dress',
#  '(1834)EPTM._Geo-Paneled_Joggers',
#  '(1422)Cropped_Open-Front_Blazer',
#  '(1511)Cutout_Sheath_Dress',
#  '(1214)Cotton_Twill_Trench_Coat',
#  '(2466)Fuzzy_Eyelash_Knit_Sweater',
#  '(4360)Scoop_Back_Bodycon_Dress',
#  '(2216)Floral_Crochet-Paneled_Dress',
#  '(666)But_First_Coffee_Tank',
#  '(1257)Crinkled_Crepe_Strapless_Romper',
#  '(4739)Strapless_Metallic_Bandage_Dress',
#  '(375)Beaded_Ornate_Print_Jumpsuit',
#  '(1043)Clean_Wash_-_Slim_Fit_Jeans',
#  '(685)Button_Cuffed_Denim_Shorts',
#  '(3677)Ombr_eacute__Heart_Muscle_Tee',
#  '(5077)Textured_Flat-Front_Shorts',
#  '(810)Chenille___Metallic_Knit_Crop_Top',
#  '(163)Abstract_Print_Trapeze_Dress',
#  '(5170)Tie-Front_Striped_Tee',
#  '(4570)Slub_Knit_T-Shirt_Dress',
#  '(4072)Pom_Pom-Trim_Macram_eacute__Sweater',
#  '(523)Boxy_Beaded_Crepe_Top',
#  '(2747)High-Waisted_Flared_Jeans',
#  '(4512)Single-Button_Blazer',
#  '(5064)Textured_Collarless_Jacket',
#  '(2733)High-Slit_Thoreau_Graphic_Dress',
#  '(2409)Forever_21_All_Day_Muscle_Tee',
#  '(3048)Las_Vegas_81_Tee',
#  '(1316)Crochet-Paneled_Sweater',
#  '(299)Bandana_Print_Tee',
#  '(352)Bead-Embellished_Top',
#  '(2139)Favorite_Soft_Knit_Tee',
#  '(4811)Striped_Baja_Hoodie',
#  '(2349)Floral_Robin_Print_Tee',
#  '(1442)Cuffed-Sleeve_Knit_Blazer',
#  '(3169)Longline_Burnout_Tee',
#  '(1285)Croc_Print_Dolphin_Shorts',
#  '(3669)Oh_Graphic_Tank',
#  '(1984)Essential_Woven_Front_Tee',
#  '(905)Civil_Regime_Mesh_Bomber_Jacket',
#  '(2931)LEEF_PARIS_Splatter_Print_Tee',
#  '(3737)Open_Knit_Crew_Neck_Sweater',
#  '(5252)Tribal_Print_Dolman_Cardigan',
#  '(190)Abstract_Striped_Bodycon_Skirt',
#  '(1174)Contrast-Paneled_Henley',
#  '(2035)Faded_Pocket_Tee',
#  '(1522)DEFYANT_D_Graphic_Tee',
#  '(445)Belted_Wrap_Coat',
#  '(4517)Sky_Culture_Kid_Cloud_Stars_Tee',
#  '(1769)Draped_Shawl_Collar_Coat',
#  '(5558)Wutever_Pocket_Tee',
#  '(2807)Hooded_Varsity_Jacket',
#  '(2612)Heathered_High-Slit_Hooded_Midi_Dress',
#  '(2236)Floral_Fit___Flare_Dress',
#  '(3570)Mixed_Knit_Cowl_Neck_Sweater',
#  '(374)Beaded_Mini_Skirt',
#  '(4536)Sleeveless_Zip-Front_Hoodie',
#  '(3488)Metallic_Maxi_Dress',
#  '(5117)Textured_Stripe_Cowl_Neck_Sweater',
#  '(5258)Tribal_Print_Fringe_Cami_Dress',
#  '(3041)Lady_Lace_Mini_Skirt',
#  '(4838)Striped_Crew_Neck_Dress',
#  '(2081)Faux_Leather_Combo_Jumpsuit',
#  '(1671)Distressed_Mineral_Wash_Jeans',
#  '(5273)Tribal_Print_Paneled_Tee',
#  '(1600)Destroyed_Tee',
#  '(1817)Drop-Crotch_Denim_Joggers',
#  '(4701)Sporty_Chic_Heathered_Sweatpants',
#  '(3541)Mineral_Wash_Denim_Shorts',
#  '(3283)Manhattan_Graphic_Tee',
#  '(1572)Denim_Cutout_Dress',
#  '(1447)Cuffed_Chino_Shorts',
#  '(2567)Halter_Maxi_Dress',
#  '(1412)Crocheted_Tank',
#  '(164)Abstract_Print_Tulip-Cut_Top',
#  '(3963)Plaid_Pocket_Tee',
#  '(2203)Floral_Burnout_Boxy_Tee',
#  '(1190)Contrast_Mesh-Paneled_Sweatpants',
#  '(3150)Linen_Chiffon_Tee',
#  '(1110)Colorblock-Striped_Muscle_Tee',
#  '(3777)Ornate_Print_Skirt',
#  '(4681)Speckled_Geo-Patterned_Sweater',
#  '(617)Boxy_Textured_Top',
#  '(4477)Shirred_Surplice-Front_Romper',
#  '(3037)Ladder_Cutout_Halter_Tank',
#  '(1343)Crochet-Trimmed_Medallion_Print_Tank',
#  '(5308)Tropical_Print_Fit___Flare_Dress',
#  '(1613)Diamond_Open-Knit_Cardigan',
#  '(1890)Embroidered_Chiffon_Blouse',
#  '(3149)Linen_Chambray_Shorts',
#  '(3944)Pintucked_Mini_Skirt',
#  '(5326)Tulip-Back_Chiffon_Blazer',
#  '(3868)Palm_Springs_Muscle_Tee',
#  '(2795)Hooded_Puffer_Jacket',
#  '(4237)Rolled-Up_Distressed_Shorts',
#  '(1737)Dotted_Stripes_Tank',
#  '(1792)Drawstring_Chino_Shorts',
#  '(2420)Free_Spirit_Kimono',
#  '(605)Boxy_Soft-Knit_Sweater',
#  '(3889)Paneled_Stripe_Tee',
#  '(3457)Mesh_Paneled_Bodycon_Dress',
#  '(4167)Retro_Graphic_Tee',
#  '(2777)Hooded_Denim_Jacket',
#  '(4317)Ruffled_Lace_Sheath_Dress',
#  '(4781)Stretch_Fit_Mineral_Wash_Skinny_Jeans',
#  '(3499)Miami_Heat_Graphic_Tank',
#  '(3471)Mesh_Tuxedo-Striped_Sweatpants',
#  '(5115)Textured_Skater_Dress',
#  '(2649)Heathered_Performance_Capri_Leggings',
#  '(1186)Contrast_Crew_Neck_Tee',
#  '(4548)Slub_Knit_Boyfriend_Tee',
#  '(1985)Ethereal_Draped_Front_Blouse',
#  '(2583)Heathered_Cities_Graphic_Sweater',
#  '(5219)Tribal-Inspired_Chino_Shorts',
#  '(4604)Solid_Knit_Leggings',
#  '(1153)Colorblocked_Raglan_Baseball_Tee',
#  '(3206)Longline_Ribbed_Knit_Sweater',
#  '(503)Bow-Back_Abstract_Print_Top',
#  '(1895)Embroidered_Crepe_Surplice_Jumpsuit',
#  '(1951)Embroidered_Overlay_Sheath_Dress',
#  '(3792)Oversized_Floral_Print_Pocket_Tee',
#  '(2270)Floral_Lace_Peplum_Dress',
#  '(3997)Pleated_Floral_Chiffon_Dress',
#  '(2666)Heathered_Shawl_Collar_Cardigan',
#  '(5607)Zippered_Mesh-Paneled_Jacket',
#  '(914)Clashist_Sand_Art_Shift_Dress',
#  '(2329)Floral_Print_Skater_Dress',
#  '(4847)Striped_Drawstring_Shorts',
#  '(1595)Destroyed_Denim_Shorts',
#  '(3285)Map_Graphic_Tee',
#  '(3176)Longline_Crepe_Blouse',
#  '(1140)Colorblocked_Floral_Print_Tee',
#  '(4954)Striped_Tribal_Print_Leggings',
#  '(3222)Longline_Tweed_Coat',
#  '(3001)Lace_Inset_Cardigan',
#  '(1920)Embroidered_Fringe-Trim_Kimono',
#  '(3743)Organza_Overlay_Sweater',
#  '(4693)Split-Neck_Dolman_Blouse',
#  '(718)Buttoned_Pocket_Blouse',
#  '(97)Abstract_Paisley_Print_Top',
#  '(1619)Diamond_Print_Chiffon_Blouse',
#  '(4565)Slub_Knit_Pocket_Tee',
#  '(4930)Striped_Shirt_Dress',
#  '(2442)Fringed_Crochet_Tank',
#  '(1444)Cuffed-Sleeve_Pocket_Tee',
#  '(3798)Oversized_Shawl_Cardigan',
#  '(1452)Cuffed_Drawstring_Denim_Shorts',
#  '(3643)New_York_Muscle_Tee',
#  '(1994)Everyday_Skinny_Jeans',
#  '(432)Belted_Polka_Dot_Skirt',
#  '(3787)Out_West_Knit_Tank',
#  '(1992)Everyday_Maxi_Skirt',
#  '(4508)Side_Vent_Tank',
#  '(4087)Pretty_in_Grunge_Tee',
#  '(2720)High-Slit_Dropped_Hem_Tee',
#  '(2868)Kimono-Sleeved_Paisley_Blouse',
#  '(3138)Life_in_Progress_Striped_Linen-Blend_Shorts',
#  '(1084)Collarless_Crepe_Trench_Coat',
#  '(4682)Speckled_Metallic_Surplice_Dress',
#  '(1793)Drawstring_Crepe_Shorts',
#  '(1158)Colorblocked_Southwestern_Print_Tee',
#  '(144)Abstract_Print_Off-the-Shoulder_Top',
#  '(4155)Refined_Buttoned_Poncho',
#  '(2390)Fluted_Velvet_Skirt',
#  '(4822)Striped_Box-Pleated_Skirt',
#  '(4106)Quilted_Puffer_Jacket',
#  '(4151)Reason_Tropical_Print_Baseball_Jersey',
#  '(850)Chiffon-Paneled_Tee',
#  '(3793)Oversized_Floral_Print_Sweatshorts',
#  '(61)Abstract_Geo_Crop_Top',
#  '(2228)Floral_Cropped_Sweater_Tank',
#  '(2485)Garfield_and_Odie_Marled_Muscle_Tee',
#  '(1618)Diamond_Print_Cami_Jumpsuit',
#  '(1309)Crochet-Paneled_Hoodie',
#  '(4347)Satin-Paneled_Shift_Dress',
#  '(3556)Mineral_Wash_Ribbed_Tank',
#  '(5165)Tie-Dye_Sweatshorts',
#  '(3231)Loose-Knit_Longline_Tee',
#  '(4950)Striped_Topstitched_Drop-Sleeve_Sweater',
#  '(2850)Kaleidoscope_Print_Culottes',
#  '(1716)Doodle_Print-Paneled_Sweatpants',
#  '(542)Boxy_Denim_Crop_Top',
#  '(3421)Menagerie_Print_Tee',
#  '(3846)Paisley_Print_Kimono',
#  '(5004)Surplice_Woven_Dress',
#  '(3572)Mixed_Media_Knit_Tee',
#  '(3426)Mesh-Paneled_Cami_Dress',
#  '(4772)Stretch-Knit_Pencil_Skirt',
#  '(146)Abstract_Print_Peasant_Blouse',
#  '(736)Cable_Knit_Varsity_Cardigan',
#  '(4997)Surplice_Cami_Dress',
#  '(3958)Plaid_Flannel_Mini_Skirt',
#  '(3337)Marled_Knit_Sheath_Dress',
#  '(276)Athletic_Mesh_Sports_Tank',
#  '(4814)Striped_Boat_Neck_Sweater',
#  '(3908)Perfect_is_Boring_Graphic_Tee',
#  '(2495)Geo-Patterned_Lace_Fringe_Cardigan',
#  '(5056)Textured_A-Line_Dress',
#  '(1915)Embroidered_Floral_Pattern_Blouse',
#  '(4567)Slub_Knit_Sweater',
#  '(4747)Strapless_Skort_Romper',
#  '(5586)Zipped_Lace_Dress',
#  '(1770)Draped_Surplice_Blouse',
#  '(4736)Strapless_Knot-Front_Romper',
#  '(2474)Fuzzy_Plaid_Skirt',
#  '(4035)Pleated_Windowpane_Skirt',
#  '(3649)No_Coffee_Graphic_Tee',
#  '(4679)Speckled_Chambray_Shorts',
#  '(3773)Ornate_Print_Harem_Jumpsuit',
#  '(3009)Lace_Panel_Pintucked_Blouse',
#  '(4816)Striped_Bodycon_Dress',
#  '(1707)Do_Not_Care_Striped_Tee',
#  '(4931)Striped_Slub_Knit_Tank',
#  '(3152)Linen_Crew_Neck_Tee',
#  '(1079)Collared_Surplice_Jumpsuit',
#  '(2353)Floral_Smile_Tee',
#  '(5492)Wave_Print_Tee',
#  '(4228)Ripped___Frayed_Denim_Cutoffs',
#  '(1058)Cloud_Wash_Distressed_Cutoffs',
#  '(1277)Crisscross_Back_Swiss_Dot_Dress',
#  '(2054)Faux_Fur_Collar_Waffle_Knit_Cardigan',
#  '(2698)Hello_Kitty_PJ_Romper',
#  '(241)Always_Be_Chic_Top',
#  '(5244)Tribal_Print_Combo_Maxi_Dress',
#  '(4282)Rose_Print_Romper',
#  '(1063)Clustered_Floral_Heathered_Tee',
#  '(159)Abstract_Print_Surplice_Top',
#  '(2184)Floral-Embroidered_Halter_Romper',
#  '(2760)High-Waisted_Yoga_Shorts',
#  '(586)Boxy_Pintucked_Top',
#  '(4987)Sunflower_Print_Jumpsuit',
#  '(869)Chiffon_Shift_Dress',
#  '(3402)Matelot_Denim_Shorts',
#  '(408)Belted_Crotchet_Combo_Dress',
#  '(310)Baroque_Floral_Surplice_Top',
#  '(3442)Mesh-Paneled_Workout_Shorts',
#  '(1816)Dreaming_And_Scheming_Hoodie',
#  '(4872)Striped_Ikat_Drawstring_Shorts',
#  '(2641)Heathered_Metallic_Bodycon_Dress',
#  '(1885)Embroidered-Mesh_Drop-Waist_Cami_Dress',
#  '(4184)Ribbed_Button-Down_Tank',
#  '(4643)Southwestern_Print_Braided_Strap_Maxi_Dress',
#  '(2825)Iguana_Print_Tee',
#  '(3886)Paneled_Knit_Sweatpants',
#  '(2646)Heathered_Open-Knit_Sweater',
#  '(3873)Palm_Tree_Print_Tee',
#  '(4013)Pleated_Maxi_Skirt',
#  '(3395)Matchstick_Print_Surplice_Dress',
#  '(507)Bow-Front_Woven_Top',
#  '(2181)Floral-Embroidered_Cami_Romper',
#  '(2403)Foldover_Athletic_Sweatpants',
#  '(3341)Marled_Knit_Sweatpants',
#  '(4331)Rugby_Striped_Crew_Neck_Sweater',
#  '(3732)Open-Mesh_Midi_Dress',
#  '(3090)Leopard___Lace_Slip_Dress',
#  '(5511)Whipstitched_Shorts',
#  '(654)Bull_Graphic_Muscle_Tee',
#  '(543)Boxy_Distressed_Tee',
#  '(413)Belted_Floral_Print_Dress',
#  '(684)Button-Tab_Ankle_Chinos',
#  '(3872)Palm_Tree_Print_Shorts',
#  '(800)Champagne_Slub_Knit_Top',
#  '(5032)Tasseled_Abstract_Floral_Cardigan',
#  '(5037)Tasseled_Lace-Up_Sweater',
#  '(150)Abstract_Print_Pleated_Dress',
#  '(3680)Ombre-Paneled_Workout_Leggings',
#  '(5220)Tribal-Inspired_Crochet_Dress',
#  '(643)Brooklyn_Nets_Baseball_Tee',
#  '(1386)Crochet_Racerback_Tank',
#  '(20)Abstract_Animal_Print_Dress',
#  '(1780)Drapey_Trench_Jacket',
#  '(3328)Marled_Knit_Hooded_Sweater',
#  '(3543)Mineral_Wash_Drawstring_Shorts',
#  '(5341)Tupac_Muscle_Tee',
#  '(4910)Striped_Paisley_Print_Romper',
#  '(3536)Mineral_Wash_Denim_Cutoffs',
#  '(2331)Floral_Print_Slit_Maxi_Dress',
#  '(354)Beaded-Trim_Chiffon_Tank',
#  '(4479)Shop_At_Forever_21_Tee',
#  '(1844)EPTM._Striped_Round-Hem_Tee',
#  '(2347)Floral_Printed_Side-Tie_Blouse',
#  '(1345)Crochet-Trimmed_Muscle_Tee',
#  '(4836)Striped_Cotton_Shorts',
#  '(1280)Crisscross_Cutout_Back_Tee',
#  '(3242)Love_Graphic_Marled_Sweatpants',
#  '(4573)Slub_Knit_Trapeze_Tee',
#  '(360)Beaded_Chiffon_Mini_Skirt',
#  '(4576)Smocked-Back_Fit___Flare_Dress',
#  '(1723)Dotted_Bow_Blouse',
#  '(3815)Painted_Floral_Maxi_Dress',
#  '(4765)Strappy_V-Back_Jumpsuit',
#  '(4963)Striped_V-Neck_Jersey_Tee',
#  '(2205)Floral_Button-Front_Dress',
#  '(116)Abstract_Print_Chiffon_Joggers',
#  '(3761)Ornate_Floral_Print_Dress',
#  '(4357)Scalloped_Lace_Cardigan',
#  '(904)Civil_Regime_Graphic_Sweatpants',
#  '(2187)Floral-Embroidered_Mesh_Dress',
#  '(951)Classic_Double-Breasted_Trench_Coat',
#  '(99)Abstract_Pattern_Bodycon_Dress',
#  '(3259)Low_Rise-_Ankle_Skinny_Jeans',
#  '(4008)Pleated_High-Waisted_Shorts',
#  '(3089)Lemon_Print_Shorts',
#  '(3078)Leaf_Print-Sleeve_Tee',
#  '(280)Audrey_Hepburn_Tank_Top',
#  '(3388)Married_To_The_Mob_Next_Tee',
#  '(2536)Get_Over_Graphic_Tee',
#  '(4595)So_Much_Internet_Tee',
#  '(4651)Southwestern_Print_Dolman_Cardigan',
#  '(4668)Southwestern_Print_Tank',
#  '(1269)Crisscross-Back_Sheath_Dress',
#  '(1685)Distressed_Suspender_Jeans',
#  '(2743)High-Waisted_Denim_Shorts',
#  '(369)Beaded_Halter_Bodycon_Dress',
#  '(3564)Minnie_Mouse_Muscle_Tee',
#  '(245)Anchor_Print_Shorts',
#  '(2057)Faux_Fur_Jacket',
#  '(1566)Definition_of_Love_Tee',
#  '(3854)Paisley_Print_Sun_Dress',
#  '(4977)Studio_Stirrup_Leggings',
#  '(4862)Striped_Geo_Pocket_Tank',
#  '(3731)Open-Knit_Tasseled_Cardigan',
#  '(1940)Embroidered_Mesh-Back_Tank',
#  '(1733)Dotted_Kick-Pleat_Tank',
#  '(1438)Cubist_Print_V-Back_Romper',
#  '(452)Bike_Print_Tee',
#  '(290)Balzac_Print_Sweatpants',
#  '(680)Button-Front_Drawstring_Romper',
#  '(2606)Heathered_Drawstring_Sweatpants',
#  '(4751)Strapless_Tribal_Print_Dress',
#  '(3711)Open-Front_Pointelle_Cardigan',
#  '(2520)Geo_Print_Swim_Trunks',
#  '(3960)Plaid_Fringe_Poncho',
#  '(5274)Tribal_Print_Peasant_Blouse',
#  '(1569)Denim_Bodycon_Dress',
#  '(5100)Textured_Knit_Varsity_Sweater',
#  '(130)Abstract_Print_Flounce_Maxi_Dress',
#  '(5053)Texture-Striped_Drawstring_Shorts',
#  '(1562)Deep_V-Neck_Halter_Dress',
#  '(776)Cap-Sleeved_Slub-Knit_Top',
#  '(4793)Stripe_Fuzzy_Cardigan',
#  '(323)Baroque_Print_High-Neck_Romper',
#  '(5049)Terry_Knit_Dolphin_Hem_Shorts',
#  '(1231)Crepe_Fit___Flare_Dress',
#  '(301)Barbie_Muscle_Tee',
#  '(185)Abstract_Stripe_Joggers',
#  '(5328)Tulip-Back_Tank',
#  '(1006)Classic_Skinny_Jeans',
#  '(1400)Crocheted_Gauze_Maxi_Dress',
#  '(4831)Striped_Chiffon_Blouse',
#  '(5280)Tribal_Print_Scuba_Knit_Dress',
#  '(4130)Rainbow_Print_Workout_Leggings',
#  '(1800)Drawstring_Floral_Dolphin_Shorts',
#  '(3988)Pleated_Combo_Dress',
#  '(1888)Embroidered_Babydoll_Dress',
#  '(899)Civil_Graphic_Sweatpants',
#  '(941)Classic_Cuffed_Shorts',
#  '(2066)Faux_Leather-Paneled_Mesh_Jacket',
#  '(4053)Polka_Dot_Denim_Shorts',
#  '(4825)Striped_Boxy_Tank',
#  '(2111)Faux_Pearl_Knit_Cardigan',
#  '(415)Belted_High-Waisted_Shorts',
#  '(4658)Southwestern_Print_Peasant_Dress',
#  '(4268)Rose_Print_Graphic_Tee',
#  '(2553)Gone_Boho_Joggers',
#  '(938)Classic_Crop_Top',
#  '(877)Chunky_Knit_Boxy_Sweater',
#  '(4210)Ribbed_Mini_Skirt',
#  '(4695)Spoiled_Graphic_Tee',
#  '(1288)Crochet-Back_Tank',
#  '(5101)Textured_Knit_Zipper_Dress',
#  '(2029)Faded_Distressed_Jeans',
#  '(4946)Striped_T-Shirt_Dress',
#  '(37)Abstract_Diamond_Fringe_Kimono',
#  '(1889)Embroidered_Bead_Keyhole_Blouse',
#  '(601)Boxy_Slit-Sleeve_Top',
#  '(3435)Mesh-Paneled_Running_Shorts',
#  '(4985)Sunburst_Print_Workout_Shorts',
#  '(3128)Life_in_Progress_Drawstring_Striped_Joggers',
#  '(4600)Soft_Knit_Leggings',
#  '(2932)La_Joie_Graphic_Heathered_Tee',
#  '(5560)XO_Print_Crisscross-Back_Dress',
#  '(1823)Drop-Sleeved_Waffle_Knit_Cardigan',
#  '(1744)Double-Breasted_Trench_Coat',
#  '(856)Chiffon___Knit_Tee',
#  '(5530)Windowpane_Print_Skater_Skirt',
#  '(2642)Heathered_Mickey_Mouse_Tee',
#  '(475)Bodycon_Bustier_Dress',
#  '(2312)Floral_Print_Lace-Paneled_Dress',
#  '(1797)Drawstring_Denim_Dress',
#  '(669)Butterfly_Print_Maxi_Dress',
#  '(117)Abstract_Print_Colorblock_Top',
#  '(1503)Cutout_Halter_Maxi_Dress',
#  '(4133)Raw-Cut_Tank',
#  '(3607)Multi-Stripe_V-Neck_Tee',
#  '(4984)Sunburst_Print_Swim_Trunks',
#  '(3307)Marled_Drop-Sleeve_Sweater',
#  '(357)Beaded_Baroque-Patterned_Skirt',
#  '(48)Abstract_Floral_Babydoll_Dress',
#  '(3955)Pizza_Print_Tank',
#  '(5118)Textured_Stripe_Knit_Skirt',
#  '(119)Abstract_Print_Combo_Romper',
#  '(2991)Lace_Back_Linen_Cardigan',
#  '(5161)Tie-Dye_Open-Shoulder_Shift_Dress',
#  '(4180)Ribbed-Stripe_Organza_A-Line_Skirt',
#  '(1574)Denim_Dolphin_Hem_Shorts',
#  '(2300)Floral_Print_Crisscross_PJ_Romper',
#  '(4823)Striped_Boxy_Knit_Tee',
#  '(2821)Ibiza_Muscle_Tee',
#  '(1630)Dickies_Dropped-Taper_Fit_Joggers',
#  '(527)Boxy_Cable_Knit_Sweater',
#  '(3985)Pleated_Chiffon_Maxi_Dress',
#  '(610)Boxy_Striped_Knit_Top',
#  '(5163)Tie-Dye_Print_Romper',
#  '(2025)Faded_Cactus_Graphic_Tank',
#  '(143)Abstract_Print_Mesh_Tee',
#  '(2713)High-Rise_-_Flat_Front_Skinny_Jeans',
#  '(686)Button_Fly_Denim_Shorts',
#  '(4361)Scoop_Back_Sheath_Dress',
#  '(3186)Longline_Faux_Fur_Coat',
#  '(1652)Distressed_Denim_Jeans',
#  '(2712)High-Neck_Striped_Tee',
#  '(694)Buttoned_Chambray_Babydoll_Dress',
#  '(4467)Sheer_Woven_Blouse',
#  '(3034)Ladder-Back_Workout_Tank',
#  '(3506)Mickey_Mouse_Ringer_Tee',
#  '(2648)Heathered_Paris_Tee',
#  '(5576)Zip-Back_Striped_Tank',
#  '(5141)Tie-Dye_Boxy_Tee',
#  '(417)Belted_Lace_Skater_Dress',
#  '(5605)Zippered_Linen_Tee',
#  '(1275)Crisscross_Back_Knit_Dress',
#  '(2394)Flutter_Sleeve_Blouse',
#  '(4871)Striped_Hot_Dog_Tee',
#  '(5257)Tribal_Print_Fit___Flare_Dress',
#  '(1539)Daisy_Print_Dress',
#  '(967)Classic_Hooded_Duffle_Coat',
#  '(1301)Crochet-Paneled_Chambray_Dress',
#  '(4602)Soft_Stripe_Crochet_Tank',
#  '(4338)Safari_Animal_Print_Shorts',
#  '(4202)Ribbed_Knit_Hoodie',
#  '(4878)Striped_Knit_Skater_Dress',
#  '(4359)Scarf-Print_Pencil_Skirt',
#  '(3971)Pleated_A-Line_Dress',
#  '(2741)High-Waisted_Denim_Cutoffs',
#  '(559)Boxy_Heathered_Crop_Top',
#  '(5148)Tie-Dye_Cutout_Tee',
#  '(2546)Glasses_Print_Tee',
#  '(743)Caged_Back_Jumpsuit',
#  '(4525)Sleek_V-Back_Dress',
#  '(5529)Windowpane_Print_Blouse',
#  '(3596)Mon_Belle_Graphic_Tee',
#  '(3624)NYC_Muscle_Tee',
#  '(418)Belted_Lace_Trim_Shorts',
#  '(4714)Standout_Stripes_Mini_Skirt',
#  '(1559)Day_Trip_Tribal_Print_Dress',
#  '(1094)Collarless_Marled_Cardigan',
#  '(4088)Printed_Drop-Waist_Cami_Dress',
#  '(3489)Metallic_Open-Knit_Cardigan',
#  '(1504)Cutout_Knit_Bodycon_Dress',
#  '(257)Asymmetric_Printed_Wrap_Dress',
#  '(4829)Striped_Cardio_Shorts',
#  '(3413)Medallion_Print_Halter_Dress',
#  '(1314)Crochet-Paneled_Shorts',
#  '(1540)Daisy_Print_Maxi_Skirt',
#  '(334)Basic_Heathered_Tee',
#  '(4673)Space_Dye_Capri_Leggings',
#  '(3385)Married_To_The_Mob_Feminist_Tank',
#  '(3828)Paisley_High-Slit_Maxi_Dress',
#  '(786)Chambray-Sleeved_Tee',
#  '(5452)Vertical_Stripe_Tee',
#  '(4305)Ruched_V-Neck_Jumpsuit',
#  '(4646)Southwestern_Print_Crepe_Kimono',
#  '(5362)Two-Button_Chino_Suit_Jacket',
#  '(3647)Night_Moves_Surplice_Dress',
#  '(4685)Speckled_Slub_Knit_Blouse',
#  '(1570)Denim_Cami_Dress',
#  '(4861)Striped_Fuzzy_Knit_Sweater',
#  '(437)Belted_Stripe_Print_Dress',
#  '(2977)Lace-Trimmed_Fit___Flare_Dress',
#  '(3977)Pleated_Baroque_Shorts',
#  '(1157)Colorblocked_Sleeveless_Hoodie',
#  '(947)Classic_Distressed_Boyfriend_Jeans',
#  '(4650)Southwestern_Print_Denim_Joggers',
#  '(2408)For_You_Graphic_Tee',
#  '(216)Abstract_Zigzag_Maxi_Dress',
#  '(2379)Flounced_Metallic_Dotted_Cami_Dress',
#  '(890)Cities_Graphic_Boxy_Tee',
#  '(1212)Cotton_Modal_Crew_Neck_Tee',
#  '(3228)Loose-Knit_Boxy_Sweater',
#  '(1298)Crochet-Paneled_Button-Down_Blouse',
#  '(4277)Rose_Print_Maxi_Dress',
#  '(5237)Tribal_Print_A-Line_Skirt',
#  '(735)Cable_Knit_Turtleneck_Sweater',
#  '(2882)Knit_Crossback_Tee',
#  '(1953)Embroidered_Panel_Cutoffs',
#  '(1264)Crinkled_Stretch_Knit_Blouse',
#  '(5299)Tropical_Floral_Crochet_Dress',
#  '(2867)Killin_It_Muscle_Tee',
#  '(3345)Marled_Knit_Zippered_Hoodie',
#  '(474)Bob_Dylan_Graphic_Tee',
#  '(1458)Cuffed_Knit_Blazer',
#  '(1758)Draped_Cowl_Neck_Poncho',
#  '(4201)Ribbed_Knit_Flared_Dress',
#  '(443)Belted_Wide-Leg_Jumpsuit',
#  '(81)Abstract_Ikat_Print_Shorts',
#  '(5297)Tropical_Curved-Hem_Tee',
#  '(4255)Rose_Print_Babydoll_Dress',
#  '(661)Burnout_Knit_Tee',
#  '(230)Acid_Wash_Distressed_Jeans',
#  '(317)Baroque_Print_Blouse',
#  '(4058)Polka_Dot_Mesh-Paneled_Tank',
#  '(3404)Maxi_Utility_Dress',
#  '(189)Abstract_Stripe_Top',
#  '(4866)Striped_Halter_Maxi_Dress',
#  '(3240)Lost___Found_Wool-Blend_Sweater',
#  '(1089)Collarless_Faux_Leather_Moto_Jacket',
#  '(596)Boxy_Rose_Print_Tee',
#  '(4633)Southwestern_Burnout_Tee',
#  '(3927)Pinstriped_Denim_Joggers',
#  '(2665)Heathered_Seamless_Workout_Tank',
#  '(3203)Longline_Raw-Cut_Hoodie',
#  '(5186)Tile_Print_Jumpsuit',
#  '(5491)Watercolor_Tribal_Print_Shorts',
#  '(2774)Hooded_Chambray_Parka_Jacket',
#  '(252)Arrow-Printed_Tee',
#  '(95)Abstract_Paisley_Print_Jumpsuit',
#  '(2366)Floral_Tulip_Back_Tank',
#  '(1344)Crochet-Trimmed_Mixed_Print_Kimono',
#  '(148)Abstract_Print_Peasant_Top',
#  '(331)Basic_Bodycon_Dress',
#  '(3966)Plaid_Trim_Pocket_Tee',
#  '(644)Brooklyn_Nets_Graphic_Tank',
#  '(929)Classic_Cotton_Jersey_Tee',
#  '(1666)Distressed_Mickey_Muscle_Tee',
#  '(2916)LA_Graphic_Tank',
#  '(4043)Pocketed_Leggings',
#  '(1557)Darling_Dots_Denim_Shorts',
#  '(5365)Two-Tone_Chunky_Cardigan',
#  '(1496)Cutout_Back_Tank',
#  '(4974)Studded_Crepe_Tank',
#  '(823)Chevron_Knit_Crewneck_Sweater',
#  '(2781)Hooded_High-Neck_Jacket',
#  '(2871)Kitty_Print_Muscle_Tee',
#  '(1650)Distressed_Denim_Faded_Cutoffs',
#  '(2532)Geo_Tribal_Print_Muscle_Tee',
#  '(3766)Ornate_Mandala_Print_Kimono',
#  '(411)Belted_Drapey_Crepe_Jacket',
#  '(3507)Micro-Stripe_Pocket_Tee',
#  '(2393)Flutter_Self-Tie_Blouse',
#  '(1912)Embroidered_Floral_Dress',
#  '(181)Abstract_Splatter_Bodycon_Dress',
#  '(4820)Striped_Bow-Front_Romper',
#  '(4558)Slub_Knit_High-Slit_Maxi_Dress',
#  '(2800)Hooded_Stripe_Dress',
#  '(2849)Kaleidoscope_Flounce_Maxi_Dress',
#  '(865)Chiffon_Paneled_Sweater',
#  '(1123)Colorblock_Pocket_Tank',
#  '(4631)Southwestern-Printed_Jumpsuit',
#  '(322)Baroque_Print_Gauze_Jumpsuit',
#  '(1395)Crochet_Yoke_Maxi_Dress',
#  '(2325)Floral_Print_Robe_Kimono',
#  '(4156)Refined_Twill_Shorts',
#  '(4598)Soft_Floral_Leggings',
#  '(3073)Layered_Split-Front_Blouse',
#  '(5391)V-Neck_Crop_Tee',
#  '(4734)Strapless_Floral_Print_Dress',
#  '(1766)Draped_Open-Front_Jacket',
#  '(2106)Faux_Leather_Trimmed_Joggers',
#  '(5168)Tie-Dyed_Tank',
#  '(484)Boho_Suite_Peasant_Top',
#  '(2893)Knotted_Jersey_Tee',
#  '(3258)Low-Rise_Skinny_Jeans',
#  '(3599)Moon_Graphic_Ringer_Tee',
#  '(3580)Mixed_Prints_Maxi_Dress',
#  '(3576)Mixed_Print_Knit_Dress',
#  '(4351)Scallop_Lace_Pencil_Skirt',
#  '(4334)Run_Graphic_Workout_Shorts',
#  '(5534)Worldly_Girl_Cutout_Dress',
#  '(4346)Sateen_V-Neck_Dolphin_Blouse',
#  '(3309)Marled_French_Terry_Hoodie',
#  '(3961)Plaid_Knit_Sweater',
#  '(5393)V-Neck_Ribbed_Dress',
#  '(1014)Classic_Split-Neck_Blouse',
#  '(5524)Wildflower_Denim_Shorts',
#  '(1268)Crisscross-Back_Seamless_Romper',
#  '(4730)Strapless_Colorblock_Maxi_Dress',
#  '(1221)Cozy_Abstract_Cardigan',
#  '(5167)Tie-Dye_Woven_Shorts',
#  '(2043)Fancy_Little_Number_Tee',
#  '(4617)Southwestern-Patterned_Bodycon_Dress',
#  '(5256)Tribal_Print_Dress',
#  '(2083)Faux_Leather_Cutout_Jacket',
#  '(3620)My_Girls_Tank',
#  '(5383)V-Cut_Bodycon_Dress',
#  '(5065)Textured_Crepe_Maxi_Dress',
#  '(106)Abstract_Print-Sleeved_Tee',
#  '(5213)Triangle-Patterned_Sequin_Shorts',
#  '(4164)Retro_Cutout_Dress',
#  '(77)Abstract_Grid_Peplum_Top',
#  '(4834)Striped_Colorblock_Sweatpants',
#  '(5544)Woven_Leggings',
#  '(5151)Tie-Dye_Hooded_Maxi_Dress',
#  '(3623)NYC_LA_Sweatshorts',
#  '(3655)No_Way_Boxy_Hoodie',
#  '(4050)Polka_Dot_Chiffon_Dress',
#  '(2890)Knit_Skater_Dress',
#  '(2344)Floral_Print_Tulip-Hem_Shorts',
#  '(1240)Crepe_Woven_A-line_Dress',
#  '(454)Bird_Print_Kimono',
#  '(1371)Crochet_Lace_Cami_Dress',
#  '(1134)Colorblocked_Cable_Knit_Sweater',
#  '(4493)Side-Slit_Longline_Tee',
#  '(3389)Married_To_The_Mob_Shaved_My_Legs_Tank',
#  '(1859)Easy_Open-Knit_Sweater',
#  '(2348)Floral_Raglan_Sweater',
#  '(4026)Pleated_Polka_Dot_Dress',
#  '(3990)Pleated_Crepe_Woven_Blouse',
#  '(2952)Lace-Paneled_Knit_Dress',
#  '(1077)Collared_Plaid_Blouse',
#  '(340)Basquiat_Graphic_Baseball_Tee',
#  '(136)Abstract_Print_Joggers',
#  '(1702)Ditsy_Floral_Print_Jumpsuit',
#  '(2770)Hooded_Bomber_Jacket',
#  '(4812)Striped_Baseball_Tee',
#  '(4713)Standout_Mesh-Trimmed_Dress',
#  '(4345)Sateen_Floral_Maxi_Dress',
#  '(5023)Tartan_Plaid_Cuffed-Sleeve_Tee',
#  '(5164)Tie-Dye_Surplice_Romper',
#  '(4029)Pleated_Scuba_Knit_Dress',
#  '(4937)Striped_Strapless_Jumpsuit',
#  '(3968)Play_With_My_Hair_Tee',
#  '(79)Abstract_Grid_Print_Top',
#  '(681)Button-Front_Floral_Mini_Skirt',
#  '(5057)Textured_A-Line_Pocket_Dress',
#  '(4749)Strapless_Sweetheart_Dress',
#  '(4100)Quilted_Faux_Leather_Jacket',
#  '(798)Chambray_Tank_Top',
#  '(5155)Tie-Dye_Knotted_Dress',
#  '(1108)Color_Striped_Performance_Leggings',
#  '(2481)Garden_Floral_Maxi_Cardigan',
#  '(1955)Embroidered_Peasant_Dress',
#  '(4207)Ribbed_Knit_Trapeze_Dress',
#  '(752)California_66_Tie-Dye_Tank',
#  '(4649)Southwestern_Print_Cutout_Maxi_Dress',
#  '(3398)Matelass_eacute__Rose_Skater_Dress',
#  '(3084)Leaf_Print_Tee',
#  '(3753)Ornate_Crochet_Back_Romper',
#  '(3959)Plaid_Flannel_Shirt_Dress',
#  '(3752)Ornate_Caged-Back_Dress',
#  '(1805)Drawstring_Palm_Print_Shorts',
#  '(1661)Distressed_High-Waisted_Cutoffs',
#  '(4938)Striped_Stretch-Knit_Dress',
#  '(1473)Curved_Hem_Raglan_Tee',
#  '(3685)On_the_Run_Muscle_Tee',
#  '(261)Asymmetrical_Chiffon_Skirt',
#  '(1423)Cropped_Open-Knit_Sweater',
#  '(5472)Water_Print_Sarong',
#  '(1352)Crochet-Trimmed_Sweater',
#  '(4388)Scuba_Mesh_Athletic_Jacket',
#  ...]

# %%
directory = os.listdir(train_data_dir)

# %%
len(directory)
# Out:
# 5497

# %%
CLASS_DICT = {k:v for k, v in enumerate(directory)}
CLASS_DICT
# Out:
# {0: '(5598)Zippered_Faux_Leather_Joggers',
#  1: '(267)Asymmetrical_Open-Front_Blazer',
#  2: '(2166)Flat-Front_Skinny_Jeans',
#  3: '(1871)Elephant_Paisley_Print_Dress',
#  4: '(4096)Quilted_Dolphin_Shorts',
#  5: '(1052)Clean_Wash_Slim-Leg_Jeans',
#  6: '(1573)Denim_Daze_Ripped_Shorts',
#  7: '(1095)Collarless_Moto_Jacket',
#  8: '(32)Abstract_Chevron_Print_Shorts',
#  9: '(4495)Side-Slit_Maxi_Dress',
#  10: '(1587)Denim_Utility_Jumpsuit',
#  11: '(4231)Ripped_Skinny_Jeans',
#  12: '(4259)Rose_Print_Chiffon_Dress',
#  13: '(4329)Rugby_Stripe_Sweater',
#  14: '(409)Belted_Daisy_Print_Dress',
#  15: '(1131)Colorblock_Yoga_Shorts',
#  16: '(4178)Rhinestoned___Beaded_Blouse',
#  17: '(5347)Tweed_Boyfriend_Blazer',
#  18: '(781)Cascading_Layered_Shift_Dress',
#  19: '(802)Charlie_Brown_Print_Tank',
#  20: '(5307)Tropical_Print_Dress',
#  21: '(2435)French_Terry_Tee',
#  22: '(1428)Cropped_Trench_Coat',
#  23: '(1194)Contrast_Trim_Henley',
#  24: '(4944)Striped_Swim_Trunks',
#  25: '(4887)Striped_Linen_Ringer_Tee',
#  26: '(368)Beaded_Geo-Embroidered_Halter_Top',
#  27: '(254)Art_Nouveau_Floral_Print_Top',
#  28: '(4070)Polka_Dot_Woven_Shorts',
#  29: '(1462)Cuffed_Low-Rise_Denim_Shorts',
#  30: '(1169)Colored_Denim_Shorts',
#  31: '(4226)Ribbed_Turtleneck_Sweater',
#  32: '(4122)Raga_Geo_Stripe_Hooded_Cardigan',
#  33: '(4067)Polka_Dot_Swim_Trunks',
#  34: '(5312)Tropical_Print_Mini_Skirt',
#  35: '(3562)Minimal_Muse_V-Neck_Tee',
#  36: '(4034)Pleated_Wide-Leg_Culottes',
#  37: '(5313)Tropical_Print_Pocket_Tank',
#  38: '(193)Abstract_Surplice_Maxi_Dress',
#  39: '(4551)Slub_Knit_Cardigan',
#  40: '(4675)Space_Dye_Waist_Running_Shorts',
#  41: '(5102)Textured_Longline_Tee',
#  42: '(439)Belted_Trench_Coat',
#  43: '(5553)Woven_Shift_Dress',
#  44: '(1819)Drop-Sleeve_Heathered_Tee',
#  45: '(534)Boxy_Crepe_Romper',
#  46: '(141)Abstract_Print_Maxi_Skirt',
#  47: '(255)Astronaut_Print_Tank',
#  48: '(3794)Oversized_Fuzzy_Knit_Cardigan',
#  49: '(455)Bird_Print_Pocket_Tee',
#  50: '(1226)Creased-Front_Leggings',
#  51: '(5535)Woven_Bermuda_Shorts',
#  52: '(1956)Embroidered_Peasant_Tank',
#  53: '(675)Button-Down_Denim_Dress',
#  54: '(1199)Control_Sector_Reversible_Drawstring_Shorts',
#  55: '(1644)Distressed_Cloud_Wash_Cutoffs',
#  56: '(2707)High-Neck_Blouse',
#  57: '(4134)Raw-Edged_Distressed_Tank',
#  58: '(14)Abstract-Printed_Capri_Leggings',
#  59: '(2657)Heathered_Raglan_Tee',
#  60: '(2993)Lace_Cami_Jumpsuit',
#  61: '(438)Belted_Stripe_Print_Shorts',
#  62: '(186)Abstract_Stripe_Print_Jumpsuit',
#  63: '(1802)Drawstring_Hood_Shift_Dress',
#  64: '(985)Classic_Mom_Jeans',
#  65: '(5606)Zippered_Longline_Sweater',
#  66: '(5589)Zippered-Ankle_Skinny_Jeans',
#  67: '(3586)Mock_Neck_Floral_Dress',
#  68: '(4435)Shaggy_Popcorn_Knit_Sweater',
#  69: '(404)Belted_Crochet-Paneled_Dress',
#  70: '(2402)Fold-Over_Yoga_Shorts',
#  71: '(3410)Medallion_Print_Blouse',
#  72: '(1529)Dainty_Lace_Tee',
#  73: '(3896)Paris_Graphic_Dress',
#  74: '(1435)Crosshatch_Bodycon_Dress',
#  75: '(4510)Simba_Graphic_Hoodie',
#  76: '(4818)Striped_Bodycon_Skirt',
#  77: '(1048)Clean_Wash_High-Rise_Skinny_Jeans',
#  78: '(3870)Palm_Tree_Graphic_Tee',
#  79: '(1724)Dotted_Chambray_Babydoll_Dress',
#  80: '(2062)Faux_Gem_Woven_Cardigan',
#  81: '(3903)Patterned_Knit_Sweater',
#  82: '(3273)Malibu_Beach_Muscle_Tee',
#  83: '(3657)Notched_Open-Front_Textured_Blazer',
#  84: '(3534)Mineral_Wash_Cutoffs',
#  85: '(2299)Floral_Print_Crepe_Skirt',
#  86: '(339)Basquiat_Crown_Tee',
#  87: '(3825)Paisley_Floral_A-Line_Dress',
#  88: '(2887)Knit_Romper',
#  89: '(1363)Crochet_Denim_Cutoffs',
#  90: '(2881)Knit_Crew_Neck_Sweater',
#  91: '(4243)Romantic_Rose_Dress',
#  92: '(2201)Floral_Bow-Front_Shorts',
#  93: '(3125)Life_in_Progress_Distressed_Low-Rise_Skinny_Jeans',
#  94: '(183)Abstract_Stripe_Bodycon_Dress',
#  95: '(4422)Sequined_Chevron_Pattern_Shorts',
#  96: '(4324)Ruffled_Trim_Sweater',
#  97: '(3898)Paris_Graphic_Tee',
#  98: '(229)Acid_Wash_Distressed_Cutoffs',
#  99: '(1815)Dreamcatcher_Muscle_Tee',
#  100: '(1114)Colorblock_Cutout_Jumpsuit',
#  101: '(2055)Faux_Fur_Collared_Zippered_Coat',
#  102: '(2966)Lace-Paneled_Sweater',
#  103: '(2013)Eyelash_Lace_Pleated_Dress',
#  104: '(96)Abstract_Paisley_Print_Kimono',
#  105: '(5354)Twist-Back_Colorblocked_Dress',
#  106: '(5270)Tribal_Print_Maxi_Dress',
#  107: '(1238)Crepe_Shawl_Collar_Blazer',
#  108: '(1196)Contrast_Waist_Sweatpants',
#  109: '(954)Classic_Faded_Denim_Jacket',
#  110: '(5336)Tulle_Overlay_Cami_Dress',
#  111: '(3217)Longline_Striped_Cardigan',
#  112: '(1324)Crochet-Trimmed_Cami_Fit___Flare_Dress',
#  113: '(1467)Cuffed_Tee_Shirt_Dress',
#  114: '(1648)Distressed_Denim_Bermuda_Shorts',
#  115: '(298)Bandana_Print_Sweatshorts',
#  116: '(917)Classic_Baseball_Tee',
#  117: '(2128)Favorite_Capri_Leggings',
#  118: '(1031)Classic_Wash_-_Skinny_Jeans',
#  119: '(4545)Slouchy_Twill_Utility_Jacket',
#  120: '(5275)Tribal_Print_Pleated_Dress',
#  121: '(1564)Deep_V-Neck_Sweater',
#  122: '(662)Burnout_Pocket_Tee',
#  123: '(4)36_Plaid_Shirt_Dress',
#  124: '(4494)Side-Slit_Marled_Dress',
#  125: '(5429)Varsity_Dreamer_Graphic_Tee',
#  126: '(1695)Ditsy_Floral_Jersey_Dress',
#  127: '(2145)Femme_Fatale_Crochet_Dress',
#  128: '(919)Classic_Bootcut_Jeans',
#  129: '(4374)Scuba_Knit_Collared_Jacket',
#  130: '(1830)Duo-Stripe_Tee',
#  131: '(3145)Linen-Blend_Shorts',
#  132: '(266)Asymmetrical_Loose_Knit_Top',
#  133: '(1183)Contrast-Trimmed_Tank',
#  134: '(2362)Floral_Tribal_Print_Shorts',
#  135: '(1957)Embroidered_Pintucked_Blouse',
#  136: '(2732)High-Slit_Tartan_Plaid_Midi_Dress',
#  137: '(347)Be_True_Cutoff_Tee',
#  138: '(1192)Contrast_Mesh_Pencil_Skirt',
#  139: '(758)Camera_Grid_Muscle_Tee',
#  140: '(2289)Floral_Print_Babydoll_Dress',
#  141: '(5456)Voila_Graphic_Muscle_Tee',
#  142: '(497)Botanical_Print_Shift_Dress',
#  143: '(1498)Cutout_Bandage_Dress',
#  144: '(5126)Textured_Zigzag_Bodycon_Dress',
#  145: '(1531)Daisy_Cap-Sleeved_Dress',
#  146: '(1762)Draped_Knit_Cardigan',
#  147: '(1187)Contrast_Drawstring_Denim_Shorts',
#  148: '(3441)Mesh-Paneled_T-Shirt_Dress',
#  149: '(338)Basic_V-Neck_Tee',
#  150: '(1918)Embroidered_Floral_Shift_Dress',
#  151: '(5568)Yoga_Capri_Leggings',
#  152: '(2542)Giraffe_Print_Sweater',
#  153: '(641)Brocade_Floral_Peplum_Top',
#  154: '(683)Button-Front_Pocket_Skirt',
#  155: '(4120)Raga_Floral_Crochet-Paneled_Dress',
#  156: '(5189)Time_To_Shine_Tee',
#  157: '(1582)Denim_Pencil_Skirt',
#  158: '(4137)Really_Smart_Striped_Ringer_Tee',
#  159: '(667)But_Not_Really_Muscle_Tee',
#  160: '(3840)Paisley_Print_Fit___Flare_Dress',
#  161: '(5373)Unstructured_Cargo_Shorts',
#  162: '(1873)Elephant_Print_Drawstring_Shorts',
#  163: '(3741)Organza-Paneled_Dress',
#  164: '(250)Antiqued_Floral_Denim_Shorts',
#  165: '(5128)The_Beatles_Graphic_Tank',
#  166: '(283)BRB_Graphic_Tee',
#  167: '(3936)Pintucked_Chiffon_Blouse',
#  168: '(4419)Sequined_Abstract_Pattern_Dress',
#  169: '(1803)Drawstring_Joggers',
#  170: '(2434)French_Terry_Sweatshorts',
#  171: '(4234)Road_Trip_Ready_Cardigan',
#  172: '(3353)Marled_Midi_Turtleneck_Dress',
#  173: '(4732)Strapless_Drawstring_Romper',
#  174: '(1612)Diamond_Embroidered_Shorts',
#  175: '(4844)Striped_Cutout-Back_Tank',
#  176: '(900)Civil_Longline_Mesh_Tee',
#  177: '(2258)Floral_Lace_Fit___Flare_Dress',
#  178: '(3771)Ornate_Paisley_Maxi_Skirt',
#  179: '(5325)Trust_Nobody_Muscle_Tee',
#  180: '(729)Cable_Knit_Cardigan',
#  181: '(4959)Striped_Turtle_Neck_Dress',
#  182: '(367)Beaded_Flowy_Cotton_Dress',
#  183: '(3052)Layered-Panel_Chiffon_Blouse',
#  184: '(5278)Tribal_Print_Romper',
#  185: '(713)Buttoned_Lace_Panel_Top',
#  186: '(2872)Knife-Pleated_Denim_Shorts',
#  187: '(910)Clashist_Aluminum_Foil_Print_Tee',
#  188: '(4967)Striped_Waffle_Knit_Sweater',
#  189: '(3433)Mesh-Paneled_Heathered_Performance_Tank',
#  190: '(86)Abstract_Mosaic_Racerback_Dress',
#  191: '(3504)Mickey_Mouse_Distressed_Muscle_Tee',
#  192: '(2053)Faux_Fur_Collar_Coat',
#  193: '(5344)Turtleneck_Sweater_Dress',
#  194: '(4929)Striped_Shift_Drawstring_Dress',
#  195: '(3813)Paint_Splatter_Tank',
#  196: '(5502)West_Coast_Mesh_Jersey',
#  197: '(493)Botanical_Floral_Cutout_Romper',
#  198: '(1115)Colorblock_Heathered_Capri_Leggings',
#  199: '(112)Abstract_Print_Buttoned_Romper',
#  200: '(3679)Ombr_eacute__Tank',
#  201: '(3932)Pintuck_Pleated_Blouse',
#  202: '(4292)Rose_Print_Sweatshorts',
#  203: '(836)Chiffon-Layered_Top',
#  204: '(2924)LEEF_PARIS_Abstract_Geo_Print_Shorts',
#  205: '(832)Chic_High-Waisted_Jeggings',
#  206: '(167)Abstract_Print_Twist-Back_Blouse',
#  207: '(647)Brooklyn_Nets_Logo_Hoodie',
#  208: '(925)Classic_Cardigan',
#  209: '(2454)Fringed_Shawl_Collar_Cardigan',
#  210: '(1693)Ditsy_Floral_Babydoll_Dress',
#  211: '(4048)Polka_Dot_Baseball_Tee',
#  212: '(2936)Lace-Edged_Cami_Romper',
#  213: '(94)Abstract_Paisley_Fit___Flare_Dress',
#  214: '(2405)Folk_Print_Fit___Flare_Dress',
#  215: '(3012)Lace_Paneled_Tee',
#  216: '(5438)Velveteen_Damask-Patterned_Leggings',
#  217: '(3515)Mid-Rise_-_Acid_Wash_Jeggings',
#  218: '(1646)Distressed_Cropped_Jeans',
#  219: '(2144)Felix_the_Cat_Muscle_Tee',
#  220: '(5443)Velveteen_Surplice_Dress',
#  221: '(4858)Striped_Fold-Over_Maxi_Skirt',
#  222: '(4656)Southwestern_Print_Maxi_Skirt',
#  223: '(4309)Ruffled-Sleeve_Layered_Blouse',
#  224: '(3910)Perforated_Athletic_Tank',
#  225: '(177)Abstract_Skort_Romper',
#  226: '(4045)Pointelle_Knit_Crop_Tank',
#  227: '(1253)Crinkled_Asymmetrical_Kimono',
#  228: '(4115)Racerback_Floral_A-Line_Dress',
#  229: '(2096)Faux_Leather_Panel_Hoodie',
#  230: '(4578)Smocked_Drawstring_Shorts',
#  231: '(1785)Drawstring_Camo_Shorts',
#  232: '(3112)Life_In_Progress_Wrap_Belt_Chambray_Dress',
#  233: '(5029)Tassel-Trimmed_Shorts',
#  234: '(5420)Varsity-Striped_Piqu_eacute__Track_Jacket',
#  235: '(2377)Flounced_Floral_Dress',
#  236: '(3265)M-Slit_Knit_Maxi_Skirt',
#  237: '(4022)Pleated_Peasant_Blouse',
#  238: '(1741)Double-Breasted_Blazer',
#  239: '(3589)Mock_Neck_Tee',
#  240: '(3776)Ornate_Print_Shorts',
#  241: '(5184)Tile_Print_Fit___Flare_Dress',
#  242: '(2507)Geo_Pattern_Bodycon_Dress',
#  243: '(4152)Reason_Woke_Up_Like_This_Tee',
#  244: '(4127)Raglan_Sleeve_Tee',
#  245: '(3544)Mineral_Wash_Drawstring_Sweatpants',
#  246: '(573)Boxy_Medallion_Print_Top',
#  247: '(25)Abstract_Brushstroke_Print_Pencil_Skirt',
#  248: '(1576)Denim_Drawstring_Jumpsuit',
#  249: '(4614)Southwestern-Inspired_Knit_Leggings',
#  250: '(248)Animal_Print_Satin_Blouse',
#  251: '(204)Abstract_Tribal_Print_Halter_Jumpsuit',
#  252: '(1868)Elegant_Crochet_Lace_Dress',
#  253: '(1453)Cuffed_Drawstring_Shorts',
#  254: '(4080)Posh_Tube_Dress',
#  255: '(4671)Southwestern_Stripe_Print_Dress',
#  256: '(2315)Floral_Print_Mesh_Dress',
#  257: '(4312)Ruffled_Floral_Blouse',
#  258: '(1416)Cropped_Crew_Neck_Tee',
#  259: '(4031)Pleated_Square_Neck_Dress',
#  260: '(4279)Rose_Print_Mini_Skirt',
#  261: '(153)Abstract_Print_Ruffled_Romper',
#  262: '(3318)Marled_Knit_Combo_Jacket',
#  263: '(5582)Zip_Collar_Bomber',
#  264: '(5012)Swiss_Dot_Crochet_Tank',
#  265: '(754)California_Graphic_Crop_Top',
#  266: '(4492)Side-Slit_Knit_Sweater',
#  267: '(2518)Geo_Print_Romper',
#  268: '(1459)Cuffed_Lined-Blend_Shorts',
#  269: '(942)Classic_Denim_Blazer',
#  270: '(853)Chiffon-Trimmed_Jumpsuit',
#  271: '(2459)Frond_Print_Mesh_Tee',
#  272: '(4386)Scuba_Knit_Sphinx_Graphic_Tee',
#  273: '(5009)Sweet_Crochet_Blouse',
#  274: '(3567)Mixed_Floral_Ruffle-Sleeve_Maxi_Dress',
#  275: '(5051)Texture-Panel_Heathered_Shorts',
#  276: '(16)Abstract-Stripe_Fuzzy_Sweater',
#  277: '(1778)Drapey_Marled_Knit_Cardigan',
#  278: '(3276)Mandala_Print_Maxi_Dress',
#  279: '(5116)Textured_Stripe_A-Line_Dress',
#  280: '(2839)Island_Graphic_Boxy_Tee',
#  281: '(5250)Tribal_Print_Cutout_Back_Dress',
#  282: '(5215)Triangle_Print_Chiffon_Blouse',
#  283: '(3386)Married_To_The_Mob_Fun_Tank',
#  284: '(2563)Grunge_Bleached_Denim_Cutoffs',
#  285: '(2044)Faux-Fur_Trimmed_Puffer_Parka',
#  286: '(633)Braided_Crew_Neck_Sweater',
#  287: '(2502)Geo_Halter_Maxi_Dress',
#  288: '(993)Classic_Pleated_Shorts',
#  289: '(2074)Faux_Leather___Tulle_Combo_Dress',
#  290: '(1067)Coated_Clean_Wash_-_Skinny_Jeans',
#  291: '(4315)Ruffled_Floral_Print_Shorts',
#  292: '(2581)Heathered_Chiffon-Paneled_Tee',
#  293: '(4387)Scuba_Knit_Varsity_Jacket',
#  294: '(3280)Mandala_Print_Tee',
#  295: '(2266)Floral_Lace_Mini_Skirt',
#  296: '(2632)Heathered_Knit_Tank',
#  297: '(416)Belted_Lace_Print_Dress',
#  298: '(4801)Stripe_Slub_Knit_Tee',
#  299: '(1514)Cutout_Sunflower_Tank',
#  300: '(2578)Heathered_Baseball_Stripe_Tee',
#  301: '(2838)Inverted_Seam_Knit_Sweater',
#  302: '(1565)Def_Leppard_Burnout_Tank',
#  303: '(3492)Metallic_Sheer-Paneled_Sweater',
#  304: '(544)Boxy_Dolman_Sleeve_Top',
#  305: '(2767)Hola_LA_Muscle_Tee',
#  306: '(3964)Plaid_Shirt_Dress',
#  307: '(550)Boxy_Fancy_Graphic_Tee',
#  308: '(3980)Pleated_Button-Front_Jumpsuit',
#  309: '(737)Cacti_Print_Tee',
#  310: '(1535)Daisy_Graphic_Muscle_Tee',
#  311: '(2594)Heathered_Crossover-Waist_Shorts',
#  312: '(4948)Striped_Textured_Sweater',
#  313: '(18)Abstract-Trimmed_Knit_Tank',
#  314: '(1945)Embroidered_Mesh_Gauze_Blouse',
#  315: '(3547)Mineral_Wash_Hooded_Dress',
#  316: '(2165)Flat-Front_Shorts',
#  317: '(2688)Heathered_Waffle_Knit_Baseball_Tee',
#  318: '(1390)Crochet_Trim_Belted_Romper',
#  319: '(1877)Elephant_Print_Tee',
#  320: '(1874)Elephant_Print_Maxi_Dress',
#  321: '(2202)Floral_Brocade_A-Line_Dress',
#  322: '(4572)Slub_Knit_Tee',
#  323: '(2603)Heathered_Drawstring_Joggers',
#  324: '(4266)Rose_Print_Fit___Flare_Dress',
#  325: '(4885)Striped_Linen_Belted_Shorts',
#  326: '(874)Chiffon_Twist-Front_Top',
#  327: '(3188)Longline_Floral_Lace_Cardigan',
#  328: '(4923)Striped_Sateen_Pencil_Skirt',
#  329: '(2921)LA_NY_Graphic_Tee',
#  330: '(3000)Lace_Inset_Cami_Dress',
#  331: '(173)Abstract_Printed_Romper',
#  332: '(1887)Embroidered-Trim_Cami_Dress',
#  333: '(2370)Floral_Wrap-Front_Maxi_Skirt',
#  334: '(4108)Quilted_Sweater',
#  335: '(911)Clashist_Oil_Slick_Print_Leggings',
#  336: '(4921)Striped_Rose_Cami_Romper',
#  337: '(3529)Mineral_Wash_Athletic-Ribbed_Joggers',
#  338: '(4859)Striped_Fringe-Trim_Shawl_Cardigan',
#  339: '(2855)Kaleidoscopic_Floral_Dress',
#  340: '(1622)Diamond_Print_Halter_Maxi_Dress',
#  341: '(1834)EPTM._Geo-Paneled_Joggers',
#  342: '(1422)Cropped_Open-Front_Blazer',
#  343: '(1511)Cutout_Sheath_Dress',
#  344: '(1214)Cotton_Twill_Trench_Coat',
#  345: '(2466)Fuzzy_Eyelash_Knit_Sweater',
#  346: '(4360)Scoop_Back_Bodycon_Dress',
#  347: '(2216)Floral_Crochet-Paneled_Dress',
#  348: '(666)But_First_Coffee_Tank',
#  349: '(1257)Crinkled_Crepe_Strapless_Romper',
#  350: '(4739)Strapless_Metallic_Bandage_Dress',
#  351: '(375)Beaded_Ornate_Print_Jumpsuit',
#  352: '(1043)Clean_Wash_-_Slim_Fit_Jeans',
#  353: '(685)Button_Cuffed_Denim_Shorts',
#  354: '(3677)Ombr_eacute__Heart_Muscle_Tee',
#  355: '(5077)Textured_Flat-Front_Shorts',
#  356: '(810)Chenille___Metallic_Knit_Crop_Top',
#  357: '(163)Abstract_Print_Trapeze_Dress',
#  358: '(5170)Tie-Front_Striped_Tee',
#  359: '(4570)Slub_Knit_T-Shirt_Dress',
#  360: '(4072)Pom_Pom-Trim_Macram_eacute__Sweater',
#  361: '(523)Boxy_Beaded_Crepe_Top',
#  362: '(2747)High-Waisted_Flared_Jeans',
#  363: '(4512)Single-Button_Blazer',
#  364: '(5064)Textured_Collarless_Jacket',
#  365: '(2733)High-Slit_Thoreau_Graphic_Dress',
#  366: '(2409)Forever_21_All_Day_Muscle_Tee',
#  367: '(3048)Las_Vegas_81_Tee',
#  368: '(1316)Crochet-Paneled_Sweater',
#  369: '(299)Bandana_Print_Tee',
#  370: '(352)Bead-Embellished_Top',
#  371: '(2139)Favorite_Soft_Knit_Tee',
#  372: '(4811)Striped_Baja_Hoodie',
#  373: '(2349)Floral_Robin_Print_Tee',
#  374: '(1442)Cuffed-Sleeve_Knit_Blazer',
#  375: '(3169)Longline_Burnout_Tee',
#  376: '(1285)Croc_Print_Dolphin_Shorts',
#  377: '(3669)Oh_Graphic_Tank',
#  378: '(1984)Essential_Woven_Front_Tee',
#  379: '(905)Civil_Regime_Mesh_Bomber_Jacket',
#  380: '(2931)LEEF_PARIS_Splatter_Print_Tee',
#  381: '(3737)Open_Knit_Crew_Neck_Sweater',
#  382: '(5252)Tribal_Print_Dolman_Cardigan',
#  383: '(190)Abstract_Striped_Bodycon_Skirt',
#  384: '(1174)Contrast-Paneled_Henley',
#  385: '(2035)Faded_Pocket_Tee',
#  386: '(1522)DEFYANT_D_Graphic_Tee',
#  387: '(445)Belted_Wrap_Coat',
#  388: '(4517)Sky_Culture_Kid_Cloud_Stars_Tee',
#  389: '(1769)Draped_Shawl_Collar_Coat',
#  390: '(5558)Wutever_Pocket_Tee',
#  391: '(2807)Hooded_Varsity_Jacket',
#  392: '(2612)Heathered_High-Slit_Hooded_Midi_Dress',
#  393: '(2236)Floral_Fit___Flare_Dress',
#  394: '(3570)Mixed_Knit_Cowl_Neck_Sweater',
#  395: '(374)Beaded_Mini_Skirt',
#  396: '(4536)Sleeveless_Zip-Front_Hoodie',
#  397: '(3488)Metallic_Maxi_Dress',
#  398: '(5117)Textured_Stripe_Cowl_Neck_Sweater',
#  399: '(5258)Tribal_Print_Fringe_Cami_Dress',
#  400: '(3041)Lady_Lace_Mini_Skirt',
#  401: '(4838)Striped_Crew_Neck_Dress',
#  402: '(2081)Faux_Leather_Combo_Jumpsuit',
#  403: '(1671)Distressed_Mineral_Wash_Jeans',
#  404: '(5273)Tribal_Print_Paneled_Tee',
#  405: '(1600)Destroyed_Tee',
#  406: '(1817)Drop-Crotch_Denim_Joggers',
#  407: '(4701)Sporty_Chic_Heathered_Sweatpants',
#  408: '(3541)Mineral_Wash_Denim_Shorts',
#  409: '(3283)Manhattan_Graphic_Tee',
#  410: '(1572)Denim_Cutout_Dress',
#  411: '(1447)Cuffed_Chino_Shorts',
#  412: '(2567)Halter_Maxi_Dress',
#  413: '(1412)Crocheted_Tank',
#  414: '(164)Abstract_Print_Tulip-Cut_Top',
#  415: '(3963)Plaid_Pocket_Tee',
#  416: '(2203)Floral_Burnout_Boxy_Tee',
#  417: '(1190)Contrast_Mesh-Paneled_Sweatpants',
#  418: '(3150)Linen_Chiffon_Tee',
#  419: '(1110)Colorblock-Striped_Muscle_Tee',
#  420: '(3777)Ornate_Print_Skirt',
#  421: '(4681)Speckled_Geo-Patterned_Sweater',
#  422: '(617)Boxy_Textured_Top',
#  423: '(4477)Shirred_Surplice-Front_Romper',
#  424: '(3037)Ladder_Cutout_Halter_Tank',
#  425: '(1343)Crochet-Trimmed_Medallion_Print_Tank',
#  426: '(5308)Tropical_Print_Fit___Flare_Dress',
#  427: '(1613)Diamond_Open-Knit_Cardigan',
#  428: '(1890)Embroidered_Chiffon_Blouse',
#  429: '(3149)Linen_Chambray_Shorts',
#  430: '(3944)Pintucked_Mini_Skirt',
#  431: '(5326)Tulip-Back_Chiffon_Blazer',
#  432: '(3868)Palm_Springs_Muscle_Tee',
#  433: '(2795)Hooded_Puffer_Jacket',
#  434: '(4237)Rolled-Up_Distressed_Shorts',
#  435: '(1737)Dotted_Stripes_Tank',
#  436: '(1792)Drawstring_Chino_Shorts',
#  437: '(2420)Free_Spirit_Kimono',
#  438: '(605)Boxy_Soft-Knit_Sweater',
#  439: '(3889)Paneled_Stripe_Tee',
#  440: '(3457)Mesh_Paneled_Bodycon_Dress',
#  441: '(4167)Retro_Graphic_Tee',
#  442: '(2777)Hooded_Denim_Jacket',
#  443: '(4317)Ruffled_Lace_Sheath_Dress',
#  444: '(4781)Stretch_Fit_Mineral_Wash_Skinny_Jeans',
#  445: '(3499)Miami_Heat_Graphic_Tank',
#  446: '(3471)Mesh_Tuxedo-Striped_Sweatpants',
#  447: '(5115)Textured_Skater_Dress',
#  448: '(2649)Heathered_Performance_Capri_Leggings',
#  449: '(1186)Contrast_Crew_Neck_Tee',
#  450: '(4548)Slub_Knit_Boyfriend_Tee',
#  451: '(1985)Ethereal_Draped_Front_Blouse',
#  452: '(2583)Heathered_Cities_Graphic_Sweater',
#  453: '(5219)Tribal-Inspired_Chino_Shorts',
#  454: '(4604)Solid_Knit_Leggings',
#  455: '(1153)Colorblocked_Raglan_Baseball_Tee',
#  456: '(3206)Longline_Ribbed_Knit_Sweater',
#  457: '(503)Bow-Back_Abstract_Print_Top',
#  458: '(1895)Embroidered_Crepe_Surplice_Jumpsuit',
#  459: '(1951)Embroidered_Overlay_Sheath_Dress',
#  460: '(3792)Oversized_Floral_Print_Pocket_Tee',
#  461: '(2270)Floral_Lace_Peplum_Dress',
#  462: '(3997)Pleated_Floral_Chiffon_Dress',
#  463: '(2666)Heathered_Shawl_Collar_Cardigan',
#  464: '(5607)Zippered_Mesh-Paneled_Jacket',
#  465: '(914)Clashist_Sand_Art_Shift_Dress',
#  466: '(2329)Floral_Print_Skater_Dress',
#  467: '(4847)Striped_Drawstring_Shorts',
#  468: '(1595)Destroyed_Denim_Shorts',
#  469: '(3285)Map_Graphic_Tee',
#  470: '(3176)Longline_Crepe_Blouse',
#  471: '(1140)Colorblocked_Floral_Print_Tee',
#  472: '(4954)Striped_Tribal_Print_Leggings',
#  473: '(3222)Longline_Tweed_Coat',
#  474: '(3001)Lace_Inset_Cardigan',
#  475: '(1920)Embroidered_Fringe-Trim_Kimono',
#  476: '(3743)Organza_Overlay_Sweater',
#  477: '(4693)Split-Neck_Dolman_Blouse',
#  478: '(718)Buttoned_Pocket_Blouse',
#  479: '(97)Abstract_Paisley_Print_Top',
#  480: '(1619)Diamond_Print_Chiffon_Blouse',
#  481: '(4565)Slub_Knit_Pocket_Tee',
#  482: '(4930)Striped_Shirt_Dress',
#  483: '(2442)Fringed_Crochet_Tank',
#  484: '(1444)Cuffed-Sleeve_Pocket_Tee',
#  485: '(3798)Oversized_Shawl_Cardigan',
#  486: '(1452)Cuffed_Drawstring_Denim_Shorts',
#  487: '(3643)New_York_Muscle_Tee',
#  488: '(1994)Everyday_Skinny_Jeans',
#  489: '(432)Belted_Polka_Dot_Skirt',
#  490: '(3787)Out_West_Knit_Tank',
#  491: '(1992)Everyday_Maxi_Skirt',
#  492: '(4508)Side_Vent_Tank',
#  493: '(4087)Pretty_in_Grunge_Tee',
#  494: '(2720)High-Slit_Dropped_Hem_Tee',
#  495: '(2868)Kimono-Sleeved_Paisley_Blouse',
#  496: '(3138)Life_in_Progress_Striped_Linen-Blend_Shorts',
#  497: '(1084)Collarless_Crepe_Trench_Coat',
#  498: '(4682)Speckled_Metallic_Surplice_Dress',
#  499: '(1793)Drawstring_Crepe_Shorts',
#  500: '(1158)Colorblocked_Southwestern_Print_Tee',
#  501: '(144)Abstract_Print_Off-the-Shoulder_Top',
#  502: '(4155)Refined_Buttoned_Poncho',
#  503: '(2390)Fluted_Velvet_Skirt',
#  504: '(4822)Striped_Box-Pleated_Skirt',
#  505: '(4106)Quilted_Puffer_Jacket',
#  506: '(4151)Reason_Tropical_Print_Baseball_Jersey',
#  507: '(850)Chiffon-Paneled_Tee',
#  508: '(3793)Oversized_Floral_Print_Sweatshorts',
#  509: '(61)Abstract_Geo_Crop_Top',
#  510: '(2228)Floral_Cropped_Sweater_Tank',
#  511: '(2485)Garfield_and_Odie_Marled_Muscle_Tee',
#  512: '(1618)Diamond_Print_Cami_Jumpsuit',
#  513: '(1309)Crochet-Paneled_Hoodie',
#  514: '(4347)Satin-Paneled_Shift_Dress',
#  515: '(3556)Mineral_Wash_Ribbed_Tank',
#  516: '(5165)Tie-Dye_Sweatshorts',
#  517: '(3231)Loose-Knit_Longline_Tee',
#  518: '(4950)Striped_Topstitched_Drop-Sleeve_Sweater',
#  519: '(2850)Kaleidoscope_Print_Culottes',
#  520: '(1716)Doodle_Print-Paneled_Sweatpants',
#  521: '(542)Boxy_Denim_Crop_Top',
#  522: '(3421)Menagerie_Print_Tee',
#  523: '(3846)Paisley_Print_Kimono',
#  524: '(5004)Surplice_Woven_Dress',
#  525: '(3572)Mixed_Media_Knit_Tee',
#  526: '(3426)Mesh-Paneled_Cami_Dress',
#  527: '(4772)Stretch-Knit_Pencil_Skirt',
#  528: '(146)Abstract_Print_Peasant_Blouse',
#  529: '(736)Cable_Knit_Varsity_Cardigan',
#  530: '(4997)Surplice_Cami_Dress',
#  531: '(3958)Plaid_Flannel_Mini_Skirt',
#  532: '(3337)Marled_Knit_Sheath_Dress',
#  533: '(276)Athletic_Mesh_Sports_Tank',
#  534: '(4814)Striped_Boat_Neck_Sweater',
#  535: '(3908)Perfect_is_Boring_Graphic_Tee',
#  536: '(2495)Geo-Patterned_Lace_Fringe_Cardigan',
#  537: '(5056)Textured_A-Line_Dress',
#  538: '(1915)Embroidered_Floral_Pattern_Blouse',
#  539: '(4567)Slub_Knit_Sweater',
#  540: '(4747)Strapless_Skort_Romper',
#  541: '(5586)Zipped_Lace_Dress',
#  542: '(1770)Draped_Surplice_Blouse',
#  543: '(4736)Strapless_Knot-Front_Romper',
#  544: '(2474)Fuzzy_Plaid_Skirt',
#  545: '(4035)Pleated_Windowpane_Skirt',
#  546: '(3649)No_Coffee_Graphic_Tee',
#  547: '(4679)Speckled_Chambray_Shorts',
#  548: '(3773)Ornate_Print_Harem_Jumpsuit',
#  549: '(3009)Lace_Panel_Pintucked_Blouse',
#  550: '(4816)Striped_Bodycon_Dress',
#  551: '(1707)Do_Not_Care_Striped_Tee',
#  552: '(4931)Striped_Slub_Knit_Tank',
#  553: '(3152)Linen_Crew_Neck_Tee',
#  554: '(1079)Collared_Surplice_Jumpsuit',
#  555: '(2353)Floral_Smile_Tee',
#  556: '(5492)Wave_Print_Tee',
#  557: '(4228)Ripped___Frayed_Denim_Cutoffs',
#  558: '(1058)Cloud_Wash_Distressed_Cutoffs',
#  559: '(1277)Crisscross_Back_Swiss_Dot_Dress',
#  560: '(2054)Faux_Fur_Collar_Waffle_Knit_Cardigan',
#  561: '(2698)Hello_Kitty_PJ_Romper',
#  562: '(241)Always_Be_Chic_Top',
#  563: '(5244)Tribal_Print_Combo_Maxi_Dress',
#  564: '(4282)Rose_Print_Romper',
#  565: '(1063)Clustered_Floral_Heathered_Tee',
#  566: '(159)Abstract_Print_Surplice_Top',
#  567: '(2184)Floral-Embroidered_Halter_Romper',
#  568: '(2760)High-Waisted_Yoga_Shorts',
#  569: '(586)Boxy_Pintucked_Top',
#  570: '(4987)Sunflower_Print_Jumpsuit',
#  571: '(869)Chiffon_Shift_Dress',
#  572: '(3402)Matelot_Denim_Shorts',
#  573: '(408)Belted_Crotchet_Combo_Dress',
#  574: '(310)Baroque_Floral_Surplice_Top',
#  575: '(3442)Mesh-Paneled_Workout_Shorts',
#  576: '(1816)Dreaming_And_Scheming_Hoodie',
#  577: '(4872)Striped_Ikat_Drawstring_Shorts',
#  578: '(2641)Heathered_Metallic_Bodycon_Dress',
#  579: '(1885)Embroidered-Mesh_Drop-Waist_Cami_Dress',
#  580: '(4184)Ribbed_Button-Down_Tank',
#  581: '(4643)Southwestern_Print_Braided_Strap_Maxi_Dress',
#  582: '(2825)Iguana_Print_Tee',
#  583: '(3886)Paneled_Knit_Sweatpants',
#  584: '(2646)Heathered_Open-Knit_Sweater',
#  585: '(3873)Palm_Tree_Print_Tee',
#  586: '(4013)Pleated_Maxi_Skirt',
#  587: '(3395)Matchstick_Print_Surplice_Dress',
#  588: '(507)Bow-Front_Woven_Top',
#  589: '(2181)Floral-Embroidered_Cami_Romper',
#  590: '(2403)Foldover_Athletic_Sweatpants',
#  591: '(3341)Marled_Knit_Sweatpants',
#  592: '(4331)Rugby_Striped_Crew_Neck_Sweater',
#  593: '(3732)Open-Mesh_Midi_Dress',
#  594: '(3090)Leopard___Lace_Slip_Dress',
#  595: '(5511)Whipstitched_Shorts',
#  596: '(654)Bull_Graphic_Muscle_Tee',
#  597: '(543)Boxy_Distressed_Tee',
#  598: '(413)Belted_Floral_Print_Dress',
#  599: '(684)Button-Tab_Ankle_Chinos',
#  600: '(3872)Palm_Tree_Print_Shorts',
#  601: '(800)Champagne_Slub_Knit_Top',
#  602: '(5032)Tasseled_Abstract_Floral_Cardigan',
#  603: '(5037)Tasseled_Lace-Up_Sweater',
#  604: '(150)Abstract_Print_Pleated_Dress',
#  605: '(3680)Ombre-Paneled_Workout_Leggings',
#  606: '(5220)Tribal-Inspired_Crochet_Dress',
#  607: '(643)Brooklyn_Nets_Baseball_Tee',
#  608: '(1386)Crochet_Racerback_Tank',
#  609: '(20)Abstract_Animal_Print_Dress',
#  610: '(1780)Drapey_Trench_Jacket',
#  611: '(3328)Marled_Knit_Hooded_Sweater',
#  612: '(3543)Mineral_Wash_Drawstring_Shorts',
#  613: '(5341)Tupac_Muscle_Tee',
#  614: '(4910)Striped_Paisley_Print_Romper',
#  615: '(3536)Mineral_Wash_Denim_Cutoffs',
#  616: '(2331)Floral_Print_Slit_Maxi_Dress',
#  617: '(354)Beaded-Trim_Chiffon_Tank',
#  618: '(4479)Shop_At_Forever_21_Tee',
#  619: '(1844)EPTM._Striped_Round-Hem_Tee',
#  620: '(2347)Floral_Printed_Side-Tie_Blouse',
#  621: '(1345)Crochet-Trimmed_Muscle_Tee',
#  622: '(4836)Striped_Cotton_Shorts',
#  623: '(1280)Crisscross_Cutout_Back_Tee',
#  624: '(3242)Love_Graphic_Marled_Sweatpants',
#  625: '(4573)Slub_Knit_Trapeze_Tee',
#  626: '(360)Beaded_Chiffon_Mini_Skirt',
#  627: '(4576)Smocked-Back_Fit___Flare_Dress',
#  628: '(1723)Dotted_Bow_Blouse',
#  629: '(3815)Painted_Floral_Maxi_Dress',
#  630: '(4765)Strappy_V-Back_Jumpsuit',
#  631: '(4963)Striped_V-Neck_Jersey_Tee',
#  632: '(2205)Floral_Button-Front_Dress',
#  633: '(116)Abstract_Print_Chiffon_Joggers',
#  634: '(3761)Ornate_Floral_Print_Dress',
#  635: '(4357)Scalloped_Lace_Cardigan',
#  636: '(904)Civil_Regime_Graphic_Sweatpants',
#  637: '(2187)Floral-Embroidered_Mesh_Dress',
#  638: '(951)Classic_Double-Breasted_Trench_Coat',
#  639: '(99)Abstract_Pattern_Bodycon_Dress',
#  640: '(3259)Low_Rise-_Ankle_Skinny_Jeans',
#  641: '(4008)Pleated_High-Waisted_Shorts',
#  642: '(3089)Lemon_Print_Shorts',
#  643: '(3078)Leaf_Print-Sleeve_Tee',
#  644: '(280)Audrey_Hepburn_Tank_Top',
#  645: '(3388)Married_To_The_Mob_Next_Tee',
#  646: '(2536)Get_Over_Graphic_Tee',
#  647: '(4595)So_Much_Internet_Tee',
#  648: '(4651)Southwestern_Print_Dolman_Cardigan',
#  649: '(4668)Southwestern_Print_Tank',
#  650: '(1269)Crisscross-Back_Sheath_Dress',
#  651: '(1685)Distressed_Suspender_Jeans',
#  652: '(2743)High-Waisted_Denim_Shorts',
#  653: '(369)Beaded_Halter_Bodycon_Dress',
#  654: '(3564)Minnie_Mouse_Muscle_Tee',
#  655: '(245)Anchor_Print_Shorts',
#  656: '(2057)Faux_Fur_Jacket',
#  657: '(1566)Definition_of_Love_Tee',
#  658: '(3854)Paisley_Print_Sun_Dress',
#  659: '(4977)Studio_Stirrup_Leggings',
#  660: '(4862)Striped_Geo_Pocket_Tank',
#  661: '(3731)Open-Knit_Tasseled_Cardigan',
#  662: '(1940)Embroidered_Mesh-Back_Tank',
#  663: '(1733)Dotted_Kick-Pleat_Tank',
#  664: '(1438)Cubist_Print_V-Back_Romper',
#  665: '(452)Bike_Print_Tee',
#  666: '(290)Balzac_Print_Sweatpants',
#  667: '(680)Button-Front_Drawstring_Romper',
#  668: '(2606)Heathered_Drawstring_Sweatpants',
#  669: '(4751)Strapless_Tribal_Print_Dress',
#  670: '(3711)Open-Front_Pointelle_Cardigan',
#  671: '(2520)Geo_Print_Swim_Trunks',
#  672: '(3960)Plaid_Fringe_Poncho',
#  673: '(5274)Tribal_Print_Peasant_Blouse',
#  674: '(1569)Denim_Bodycon_Dress',
#  675: '(5100)Textured_Knit_Varsity_Sweater',
#  676: '(130)Abstract_Print_Flounce_Maxi_Dress',
#  677: '(5053)Texture-Striped_Drawstring_Shorts',
#  678: '(1562)Deep_V-Neck_Halter_Dress',
#  679: '(776)Cap-Sleeved_Slub-Knit_Top',
#  680: '(4793)Stripe_Fuzzy_Cardigan',
#  681: '(323)Baroque_Print_High-Neck_Romper',
#  682: '(5049)Terry_Knit_Dolphin_Hem_Shorts',
#  683: '(1231)Crepe_Fit___Flare_Dress',
#  684: '(301)Barbie_Muscle_Tee',
#  685: '(185)Abstract_Stripe_Joggers',
#  686: '(5328)Tulip-Back_Tank',
#  687: '(1006)Classic_Skinny_Jeans',
#  688: '(1400)Crocheted_Gauze_Maxi_Dress',
#  689: '(4831)Striped_Chiffon_Blouse',
#  690: '(5280)Tribal_Print_Scuba_Knit_Dress',
#  691: '(4130)Rainbow_Print_Workout_Leggings',
#  692: '(1800)Drawstring_Floral_Dolphin_Shorts',
#  693: '(3988)Pleated_Combo_Dress',
#  694: '(1888)Embroidered_Babydoll_Dress',
#  695: '(899)Civil_Graphic_Sweatpants',
#  696: '(941)Classic_Cuffed_Shorts',
#  697: '(2066)Faux_Leather-Paneled_Mesh_Jacket',
#  698: '(4053)Polka_Dot_Denim_Shorts',
#  699: '(4825)Striped_Boxy_Tank',
#  700: '(2111)Faux_Pearl_Knit_Cardigan',
#  701: '(415)Belted_High-Waisted_Shorts',
#  702: '(4658)Southwestern_Print_Peasant_Dress',
#  703: '(4268)Rose_Print_Graphic_Tee',
#  704: '(2553)Gone_Boho_Joggers',
#  705: '(938)Classic_Crop_Top',
#  706: '(877)Chunky_Knit_Boxy_Sweater',
#  707: '(4210)Ribbed_Mini_Skirt',
#  708: '(4695)Spoiled_Graphic_Tee',
#  709: '(1288)Crochet-Back_Tank',
#  710: '(5101)Textured_Knit_Zipper_Dress',
#  711: '(2029)Faded_Distressed_Jeans',
#  712: '(4946)Striped_T-Shirt_Dress',
#  713: '(37)Abstract_Diamond_Fringe_Kimono',
#  714: '(1889)Embroidered_Bead_Keyhole_Blouse',
#  715: '(601)Boxy_Slit-Sleeve_Top',
#  716: '(3435)Mesh-Paneled_Running_Shorts',
#  717: '(4985)Sunburst_Print_Workout_Shorts',
#  718: '(3128)Life_in_Progress_Drawstring_Striped_Joggers',
#  719: '(4600)Soft_Knit_Leggings',
#  720: '(2932)La_Joie_Graphic_Heathered_Tee',
#  721: '(5560)XO_Print_Crisscross-Back_Dress',
#  722: '(1823)Drop-Sleeved_Waffle_Knit_Cardigan',
#  723: '(1744)Double-Breasted_Trench_Coat',
#  724: '(856)Chiffon___Knit_Tee',
#  725: '(5530)Windowpane_Print_Skater_Skirt',
#  726: '(2642)Heathered_Mickey_Mouse_Tee',
#  727: '(475)Bodycon_Bustier_Dress',
#  728: '(2312)Floral_Print_Lace-Paneled_Dress',
#  729: '(1797)Drawstring_Denim_Dress',
#  730: '(669)Butterfly_Print_Maxi_Dress',
#  731: '(117)Abstract_Print_Colorblock_Top',
#  732: '(1503)Cutout_Halter_Maxi_Dress',
#  733: '(4133)Raw-Cut_Tank',
#  734: '(3607)Multi-Stripe_V-Neck_Tee',
#  735: '(4984)Sunburst_Print_Swim_Trunks',
#  736: '(3307)Marled_Drop-Sleeve_Sweater',
#  737: '(357)Beaded_Baroque-Patterned_Skirt',
#  738: '(48)Abstract_Floral_Babydoll_Dress',
#  739: '(3955)Pizza_Print_Tank',
#  740: '(5118)Textured_Stripe_Knit_Skirt',
#  741: '(119)Abstract_Print_Combo_Romper',
#  742: '(2991)Lace_Back_Linen_Cardigan',
#  743: '(5161)Tie-Dye_Open-Shoulder_Shift_Dress',
#  744: '(4180)Ribbed-Stripe_Organza_A-Line_Skirt',
#  745: '(1574)Denim_Dolphin_Hem_Shorts',
#  746: '(2300)Floral_Print_Crisscross_PJ_Romper',
#  747: '(4823)Striped_Boxy_Knit_Tee',
#  748: '(2821)Ibiza_Muscle_Tee',
#  749: '(1630)Dickies_Dropped-Taper_Fit_Joggers',
#  750: '(527)Boxy_Cable_Knit_Sweater',
#  751: '(3985)Pleated_Chiffon_Maxi_Dress',
#  752: '(610)Boxy_Striped_Knit_Top',
#  753: '(5163)Tie-Dye_Print_Romper',
#  754: '(2025)Faded_Cactus_Graphic_Tank',
#  755: '(143)Abstract_Print_Mesh_Tee',
#  756: '(2713)High-Rise_-_Flat_Front_Skinny_Jeans',
#  757: '(686)Button_Fly_Denim_Shorts',
#  758: '(4361)Scoop_Back_Sheath_Dress',
#  759: '(3186)Longline_Faux_Fur_Coat',
#  760: '(1652)Distressed_Denim_Jeans',
#  761: '(2712)High-Neck_Striped_Tee',
#  762: '(694)Buttoned_Chambray_Babydoll_Dress',
#  763: '(4467)Sheer_Woven_Blouse',
#  764: '(3034)Ladder-Back_Workout_Tank',
#  765: '(3506)Mickey_Mouse_Ringer_Tee',
#  766: '(2648)Heathered_Paris_Tee',
#  767: '(5576)Zip-Back_Striped_Tank',
#  768: '(5141)Tie-Dye_Boxy_Tee',
#  769: '(417)Belted_Lace_Skater_Dress',
#  770: '(5605)Zippered_Linen_Tee',
#  771: '(1275)Crisscross_Back_Knit_Dress',
#  772: '(2394)Flutter_Sleeve_Blouse',
#  773: '(4871)Striped_Hot_Dog_Tee',
#  774: '(5257)Tribal_Print_Fit___Flare_Dress',
#  775: '(1539)Daisy_Print_Dress',
#  776: '(967)Classic_Hooded_Duffle_Coat',
#  777: '(1301)Crochet-Paneled_Chambray_Dress',
#  778: '(4602)Soft_Stripe_Crochet_Tank',
#  779: '(4338)Safari_Animal_Print_Shorts',
#  780: '(4202)Ribbed_Knit_Hoodie',
#  781: '(4878)Striped_Knit_Skater_Dress',
#  782: '(4359)Scarf-Print_Pencil_Skirt',
#  783: '(3971)Pleated_A-Line_Dress',
#  784: '(2741)High-Waisted_Denim_Cutoffs',
#  785: '(559)Boxy_Heathered_Crop_Top',
#  786: '(5148)Tie-Dye_Cutout_Tee',
#  787: '(2546)Glasses_Print_Tee',
#  788: '(743)Caged_Back_Jumpsuit',
#  789: '(4525)Sleek_V-Back_Dress',
#  790: '(5529)Windowpane_Print_Blouse',
#  791: '(3596)Mon_Belle_Graphic_Tee',
#  792: '(3624)NYC_Muscle_Tee',
#  793: '(418)Belted_Lace_Trim_Shorts',
#  794: '(4714)Standout_Stripes_Mini_Skirt',
#  795: '(1559)Day_Trip_Tribal_Print_Dress',
#  796: '(1094)Collarless_Marled_Cardigan',
#  797: '(4088)Printed_Drop-Waist_Cami_Dress',
#  798: '(3489)Metallic_Open-Knit_Cardigan',
#  799: '(1504)Cutout_Knit_Bodycon_Dress',
#  800: '(257)Asymmetric_Printed_Wrap_Dress',
#  801: '(4829)Striped_Cardio_Shorts',
#  802: '(3413)Medallion_Print_Halter_Dress',
#  803: '(1314)Crochet-Paneled_Shorts',
#  804: '(1540)Daisy_Print_Maxi_Skirt',
#  805: '(334)Basic_Heathered_Tee',
#  806: '(4673)Space_Dye_Capri_Leggings',
#  807: '(3385)Married_To_The_Mob_Feminist_Tank',
#  808: '(3828)Paisley_High-Slit_Maxi_Dress',
#  809: '(786)Chambray-Sleeved_Tee',
#  810: '(5452)Vertical_Stripe_Tee',
#  811: '(4305)Ruched_V-Neck_Jumpsuit',
#  812: '(4646)Southwestern_Print_Crepe_Kimono',
#  813: '(5362)Two-Button_Chino_Suit_Jacket',
#  814: '(3647)Night_Moves_Surplice_Dress',
#  815: '(4685)Speckled_Slub_Knit_Blouse',
#  816: '(1570)Denim_Cami_Dress',
#  817: '(4861)Striped_Fuzzy_Knit_Sweater',
#  818: '(437)Belted_Stripe_Print_Dress',
#  819: '(2977)Lace-Trimmed_Fit___Flare_Dress',
#  820: '(3977)Pleated_Baroque_Shorts',
#  821: '(1157)Colorblocked_Sleeveless_Hoodie',
#  822: '(947)Classic_Distressed_Boyfriend_Jeans',
#  823: '(4650)Southwestern_Print_Denim_Joggers',
#  824: '(2408)For_You_Graphic_Tee',
#  825: '(216)Abstract_Zigzag_Maxi_Dress',
#  826: '(2379)Flounced_Metallic_Dotted_Cami_Dress',
#  827: '(890)Cities_Graphic_Boxy_Tee',
#  828: '(1212)Cotton_Modal_Crew_Neck_Tee',
#  829: '(3228)Loose-Knit_Boxy_Sweater',
#  830: '(1298)Crochet-Paneled_Button-Down_Blouse',
#  831: '(4277)Rose_Print_Maxi_Dress',
#  832: '(5237)Tribal_Print_A-Line_Skirt',
#  833: '(735)Cable_Knit_Turtleneck_Sweater',
#  834: '(2882)Knit_Crossback_Tee',
#  835: '(1953)Embroidered_Panel_Cutoffs',
#  836: '(1264)Crinkled_Stretch_Knit_Blouse',
#  837: '(5299)Tropical_Floral_Crochet_Dress',
#  838: '(2867)Killin_It_Muscle_Tee',
#  839: '(3345)Marled_Knit_Zippered_Hoodie',
#  840: '(474)Bob_Dylan_Graphic_Tee',
#  841: '(1458)Cuffed_Knit_Blazer',
#  842: '(1758)Draped_Cowl_Neck_Poncho',
#  843: '(4201)Ribbed_Knit_Flared_Dress',
#  844: '(443)Belted_Wide-Leg_Jumpsuit',
#  845: '(81)Abstract_Ikat_Print_Shorts',
#  846: '(5297)Tropical_Curved-Hem_Tee',
#  847: '(4255)Rose_Print_Babydoll_Dress',
#  848: '(661)Burnout_Knit_Tee',
#  849: '(230)Acid_Wash_Distressed_Jeans',
#  850: '(317)Baroque_Print_Blouse',
#  851: '(4058)Polka_Dot_Mesh-Paneled_Tank',
#  852: '(3404)Maxi_Utility_Dress',
#  853: '(189)Abstract_Stripe_Top',
#  854: '(4866)Striped_Halter_Maxi_Dress',
#  855: '(3240)Lost___Found_Wool-Blend_Sweater',
#  856: '(1089)Collarless_Faux_Leather_Moto_Jacket',
#  857: '(596)Boxy_Rose_Print_Tee',
#  858: '(4633)Southwestern_Burnout_Tee',
#  859: '(3927)Pinstriped_Denim_Joggers',
#  860: '(2665)Heathered_Seamless_Workout_Tank',
#  861: '(3203)Longline_Raw-Cut_Hoodie',
#  862: '(5186)Tile_Print_Jumpsuit',
#  863: '(5491)Watercolor_Tribal_Print_Shorts',
#  864: '(2774)Hooded_Chambray_Parka_Jacket',
#  865: '(252)Arrow-Printed_Tee',
#  866: '(95)Abstract_Paisley_Print_Jumpsuit',
#  867: '(2366)Floral_Tulip_Back_Tank',
#  868: '(1344)Crochet-Trimmed_Mixed_Print_Kimono',
#  869: '(148)Abstract_Print_Peasant_Top',
#  870: '(331)Basic_Bodycon_Dress',
#  871: '(3966)Plaid_Trim_Pocket_Tee',
#  872: '(644)Brooklyn_Nets_Graphic_Tank',
#  873: '(929)Classic_Cotton_Jersey_Tee',
#  874: '(1666)Distressed_Mickey_Muscle_Tee',
#  875: '(2916)LA_Graphic_Tank',
#  876: '(4043)Pocketed_Leggings',
#  877: '(1557)Darling_Dots_Denim_Shorts',
#  878: '(5365)Two-Tone_Chunky_Cardigan',
#  879: '(1496)Cutout_Back_Tank',
#  880: '(4974)Studded_Crepe_Tank',
#  881: '(823)Chevron_Knit_Crewneck_Sweater',
#  882: '(2781)Hooded_High-Neck_Jacket',
#  883: '(2871)Kitty_Print_Muscle_Tee',
#  884: '(1650)Distressed_Denim_Faded_Cutoffs',
#  885: '(2532)Geo_Tribal_Print_Muscle_Tee',
#  886: '(3766)Ornate_Mandala_Print_Kimono',
#  887: '(411)Belted_Drapey_Crepe_Jacket',
#  888: '(3507)Micro-Stripe_Pocket_Tee',
#  889: '(2393)Flutter_Self-Tie_Blouse',
#  890: '(1912)Embroidered_Floral_Dress',
#  891: '(181)Abstract_Splatter_Bodycon_Dress',
#  892: '(4820)Striped_Bow-Front_Romper',
#  893: '(4558)Slub_Knit_High-Slit_Maxi_Dress',
#  894: '(2800)Hooded_Stripe_Dress',
#  895: '(2849)Kaleidoscope_Flounce_Maxi_Dress',
#  896: '(865)Chiffon_Paneled_Sweater',
#  897: '(1123)Colorblock_Pocket_Tank',
#  898: '(4631)Southwestern-Printed_Jumpsuit',
#  899: '(322)Baroque_Print_Gauze_Jumpsuit',
#  900: '(1395)Crochet_Yoke_Maxi_Dress',
#  901: '(2325)Floral_Print_Robe_Kimono',
#  902: '(4156)Refined_Twill_Shorts',
#  903: '(4598)Soft_Floral_Leggings',
#  904: '(3073)Layered_Split-Front_Blouse',
#  905: '(5391)V-Neck_Crop_Tee',
#  906: '(4734)Strapless_Floral_Print_Dress',
#  907: '(1766)Draped_Open-Front_Jacket',
#  908: '(2106)Faux_Leather_Trimmed_Joggers',
#  909: '(5168)Tie-Dyed_Tank',
#  910: '(484)Boho_Suite_Peasant_Top',
#  911: '(2893)Knotted_Jersey_Tee',
#  912: '(3258)Low-Rise_Skinny_Jeans',
#  913: '(3599)Moon_Graphic_Ringer_Tee',
#  914: '(3580)Mixed_Prints_Maxi_Dress',
#  915: '(3576)Mixed_Print_Knit_Dress',
#  916: '(4351)Scallop_Lace_Pencil_Skirt',
#  917: '(4334)Run_Graphic_Workout_Shorts',
#  918: '(5534)Worldly_Girl_Cutout_Dress',
#  919: '(4346)Sateen_V-Neck_Dolphin_Blouse',
#  920: '(3309)Marled_French_Terry_Hoodie',
#  921: '(3961)Plaid_Knit_Sweater',
#  922: '(5393)V-Neck_Ribbed_Dress',
#  923: '(1014)Classic_Split-Neck_Blouse',
#  924: '(5524)Wildflower_Denim_Shorts',
#  925: '(1268)Crisscross-Back_Seamless_Romper',
#  926: '(4730)Strapless_Colorblock_Maxi_Dress',
#  927: '(1221)Cozy_Abstract_Cardigan',
#  928: '(5167)Tie-Dye_Woven_Shorts',
#  929: '(2043)Fancy_Little_Number_Tee',
#  930: '(4617)Southwestern-Patterned_Bodycon_Dress',
#  931: '(5256)Tribal_Print_Dress',
#  932: '(2083)Faux_Leather_Cutout_Jacket',
#  933: '(3620)My_Girls_Tank',
#  934: '(5383)V-Cut_Bodycon_Dress',
#  935: '(5065)Textured_Crepe_Maxi_Dress',
#  936: '(106)Abstract_Print-Sleeved_Tee',
#  937: '(5213)Triangle-Patterned_Sequin_Shorts',
#  938: '(4164)Retro_Cutout_Dress',
#  939: '(77)Abstract_Grid_Peplum_Top',
#  940: '(4834)Striped_Colorblock_Sweatpants',
#  941: '(5544)Woven_Leggings',
#  942: '(5151)Tie-Dye_Hooded_Maxi_Dress',
#  943: '(3623)NYC_LA_Sweatshorts',
#  944: '(3655)No_Way_Boxy_Hoodie',
#  945: '(4050)Polka_Dot_Chiffon_Dress',
#  946: '(2890)Knit_Skater_Dress',
#  947: '(2344)Floral_Print_Tulip-Hem_Shorts',
#  948: '(1240)Crepe_Woven_A-line_Dress',
#  949: '(454)Bird_Print_Kimono',
#  950: '(1371)Crochet_Lace_Cami_Dress',
#  951: '(1134)Colorblocked_Cable_Knit_Sweater',
#  952: '(4493)Side-Slit_Longline_Tee',
#  953: '(3389)Married_To_The_Mob_Shaved_My_Legs_Tank',
#  954: '(1859)Easy_Open-Knit_Sweater',
#  955: '(2348)Floral_Raglan_Sweater',
#  956: '(4026)Pleated_Polka_Dot_Dress',
#  957: '(3990)Pleated_Crepe_Woven_Blouse',
#  958: '(2952)Lace-Paneled_Knit_Dress',
#  959: '(1077)Collared_Plaid_Blouse',
#  960: '(340)Basquiat_Graphic_Baseball_Tee',
#  961: '(136)Abstract_Print_Joggers',
#  962: '(1702)Ditsy_Floral_Print_Jumpsuit',
#  963: '(2770)Hooded_Bomber_Jacket',
#  964: '(4812)Striped_Baseball_Tee',
#  965: '(4713)Standout_Mesh-Trimmed_Dress',
#  966: '(4345)Sateen_Floral_Maxi_Dress',
#  967: '(5023)Tartan_Plaid_Cuffed-Sleeve_Tee',
#  968: '(5164)Tie-Dye_Surplice_Romper',
#  969: '(4029)Pleated_Scuba_Knit_Dress',
#  970: '(4937)Striped_Strapless_Jumpsuit',
#  971: '(3968)Play_With_My_Hair_Tee',
#  972: '(79)Abstract_Grid_Print_Top',
#  973: '(681)Button-Front_Floral_Mini_Skirt',
#  974: '(5057)Textured_A-Line_Pocket_Dress',
#  975: '(4749)Strapless_Sweetheart_Dress',
#  976: '(4100)Quilted_Faux_Leather_Jacket',
#  977: '(798)Chambray_Tank_Top',
#  978: '(5155)Tie-Dye_Knotted_Dress',
#  979: '(1108)Color_Striped_Performance_Leggings',
#  980: '(2481)Garden_Floral_Maxi_Cardigan',
#  981: '(1955)Embroidered_Peasant_Dress',
#  982: '(4207)Ribbed_Knit_Trapeze_Dress',
#  983: '(752)California_66_Tie-Dye_Tank',
#  984: '(4649)Southwestern_Print_Cutout_Maxi_Dress',
#  985: '(3398)Matelass_eacute__Rose_Skater_Dress',
#  986: '(3084)Leaf_Print_Tee',
#  987: '(3753)Ornate_Crochet_Back_Romper',
#  988: '(3959)Plaid_Flannel_Shirt_Dress',
#  989: '(3752)Ornate_Caged-Back_Dress',
#  990: '(1805)Drawstring_Palm_Print_Shorts',
#  991: '(1661)Distressed_High-Waisted_Cutoffs',
#  992: '(4938)Striped_Stretch-Knit_Dress',
#  993: '(1473)Curved_Hem_Raglan_Tee',
#  994: '(3685)On_the_Run_Muscle_Tee',
#  995: '(261)Asymmetrical_Chiffon_Skirt',
#  996: '(1423)Cropped_Open-Knit_Sweater',
#  997: '(5472)Water_Print_Sarong',
#  998: '(1352)Crochet-Trimmed_Sweater',
#  999: '(4388)Scuba_Mesh_Athletic_Jacket',
#  ...}

# %%
gen = ImageDataGenerator(rescale=1./255)
num_classes = len(CLASS_DICT)
num_classes
# Out:
# 5497

# %%
def listdir_fullpath(d):
    return [os.path.join(d, f) for f in os.listdir(d)]

# %%
def input_triplet_gen(gen, data_dir, num_classes, batch_size):
    
    while True:
        anchor_label, neg_label = random.sample(range(0, num_classes), 2)
        
        POS_DIR = os.path.join(data_dir, CLASS_DICT[anchor_label])
        NEG_DIR = os.path.join(data_dir, CLASS_DICT[neg_label])
        
        POS_filecount = len(os.listdir(os.path.join(POS_DIR, POS_DIR.split(os.path.sep)[-1])))    #POS_DIR 파일 개수 (뎁스 2번 들어가야해서 os.path.join~ 해주기)
        NEG_filecount = len(os.listdir(os.path.join(NEG_DIR, NEG_DIR.split(os.path.sep)[-1])))   #NEG_DIR 파일 개수
        
        if  POS_filecount < batch_size or NEG_filecount < batch_size:    #파일 개수가 batch_size 미만이면 처음으로 돌아가서 클래스 다시 선택
            continue

        anchor_gen = gen.flow_from_directory(POS_DIR, 
                                             target_size=(224, 224),
                                             batch_size=batch_size,
                                             color_mode='rgb')

        pos_gen = gen.flow_from_directory(POS_DIR,
                                          target_size=(224, 224),
                                          batch_size=batch_size,
                                          color_mode='rgb')

        neg_gen = gen.flow_from_directory(NEG_DIR, 
                                          target_size=(224, 224),
                                          batch_size=batch_size,
                                          color_mode='rgb')
    
#         print("Anchor: {} , Neg: {}".format(anchor_label, neg_label))
        X1i = anchor_gen.next()
        X2i = pos_gen.next()
        X3i = neg_gen.next()
        
        yield [X1i[0], X2i[0], X3i[0]], X1i[1]

# %% [markdown]
# # 3. Create model

# %%
in_dims = (224, 224, 3)    # (28, 28, 1)
out_dims = 128

# Create the 3 inputs
anchor_in = Input(shape=in_dims, name='anchor')
pos_in = Input(shape=in_dims, name='positive')
neg_in = Input(shape=in_dims, name='negative')

# with tf.compat.v1.Session(config=config):
    # Share base network with the 3 inputs
base_network = res_base_network(in_dims, out_dims)
anchor_out = base_network(anchor_in)
pos_out = base_network(pos_in)
neg_out = base_network(neg_in)
    
merged_vector = concatenate([anchor_out, pos_out, neg_out], axis=-1)

# Define the trainable model
model = Model(inputs=[anchor_in, pos_in, neg_in], outputs=merged_vector)
model.compile(optimizer=Adam(learning_rate=0.0001, clipnorm=5.0),
                    loss=lossless_triplet_loss)

# %%
base_network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Model)             (None, 2048)              23587712
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               131200
# =================================================================
# Total params: 25,817,088
# Trainable params: 25,763,968
# Non-trainable params: 53,120
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# anchor (InputLayer)             [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# positive (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# negative (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 128)          25817088    anchor[0][0]
#                                                                  positive[0][0]
#                                                                  negative[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 384)          0           sequential[1][0]
#                                                                  sequential[2][0]
#                                                                  sequential[3][0]
# ==================================================================================================
# Total params: 25,817,088
# Trainable params: 25,763,968
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
# plot_model(base_network, to_file='detectron_base.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # 4. 이어서 학습하기

# %%
# #weights 로드
# model_weights_dir = './trained/resnet_detectron/000001-1.0883.h5'
# model.load_weights(model_weights_dir)

# %%
# model.summary()

# %% [markdown]
# # 4. Train

# %%
batch_size = 16

# %%
my_callbacks = [
    tf.keras.callbacks.ModelCheckpoint(filepath='./trained/resnet_detectron_val/{epoch:06d}-{loss:.4f}.h5')]

# %%
# Training the model
H = model.fit(input_triplet_gen(gen, train_data_dir, num_classes, batch_size),
                        steps_per_epoch = 1000, 
                        epochs=1000, 
                        validation_data = input_triplet_gen(gen, val_data_dir, num_classes, batch_size),
                        callbacks = my_callbacks)
# Out:
# WARNING:tensorflow:From <ipython-input-19-35e3ce628c60>:6: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']

# %%
# 서환
# Training the model
test_set = ImageDataGenerator(rescale = 1./255).flow_from_directory('../val',
                                            target_size = (224, 224),
                                            batch_size = 8,
                                            class_mode = 'binary')


H = model.fit_generator(input_triplet_gen(gen, train_data_dir, num_classes, batch_size),
                        steps_per_epoch = 30, 
                        epochs=1000, 
                        validation_data = test_set,
                        callbacks = my_callbacks)

# %%
#결과 확인
plt.plot(H.history['loss'])
# plt.savefig('./CNN/loss_graph.png')
# plt.legend(['loss'], loc = 'upper left')
plt.show()

# %% [markdown]
# # 5. Save model & weights

# %%
model_dir = './trained/0527_10epoch_1000steps_model.json'
model_weights_dir = './trained/0527_10epoch_1000steps_model.h5'
base_dir = './trained/0527_10epoch_1000steps_base.json'
base_weights_dir = './trained/0527_10epoch_1000steps_base.h5'

# %%
#Save model
model_json = model.to_json()
with open(model_dir, "w") as json_file : 
    json_file.write(model_json)

#Save weights
model.save_weights(model_weights_dir)
print("Saved model to disk")

# %%
#Save base network
base_json = base_network.to_json()
with open(base_dir, "w") as json_file : 
    json_file.write(base_json)

#Save weights
base_network.save_weights(base_weights_dir)
print("Saved base network to disk")

# %%
#Load base network & weights
from keras.models import model_from_json
json_file = open(base_dir, "r")
loaded_base_json = json_file.read()
json_file.close()
loaded_base_network = model_from_json(loaded_base_json)
loaded_base_network.load_weights(base_weights_dir)
print("Loaded model from disk")

# %%
model_dir = './trained/0527_10epoch_1000steps_model.json'
model_weights_dir = './trained/0527_10epoch_1000steps_model.h5'
model_weights_dir = './trained/0527_10epoch_1000steps_model.h5'

# %%
#Load base network & weights
from keras.models import model_from_json
json_file = open(model_dir, "r")
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
loaded_model.load_weights(model_weights_dir)
print("Loaded model from disk")

# %% [markdown]
# # 6. Application

# %%
def item_to_encoding(item, model):
    return model.predict(np.array([item]))

# %% [markdown]
# ## 6.1 Load test data

# %%
test_dir = '../img/img_moved2'    #클래스 5개만 있는 테스트 디렉토리

# %%
test_batch_size = 2000

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
                        data_dir,  # this is the target directory
                        target_size=(150, 150),  # 모든 이미지의 크기가 150x150로 조정됩니다.
                        batch_size=test_batch_size)

batch = test_generator.next()
images = batch[0]
labels = batch[1]

# images = images.reshape(-1, 150, 150)
labels = np.array([np.argmax(x) for x in labels])

# %%
len(set(labels))

# %%
    while True:
        anchor_label, neg_label = random.sample(range(0, num_classes), 2)
        
        POS_DIR = os.path.join(data_dir, CLASS_DICT[anchor_label])
        NEG_DIR = os.path.join(data_dir, CLASS_DICT[neg_label])
        
        POS_filecount = len(os.listdir(os.path.join(POS_DIR, POS_DIR.split(os.path.sep)[-1])))    #POS_DIR 파일 개수 (뎁스 2번 들어가야해서 os.path.join~ 해주기)
        NEG_filecount = len(os.listdir(os.path.join(NEG_DIR, NEG_DIR.split(os.path.sep)[-1])))   #NEG_DIR 파일 개수
        
        if  POS_filecount < batch_size or NEG_filecount < batch_size:    #파일 개수가 batch_size 미만이면 처음으로 돌아가서 클래스 다시 선택
            continue

        anchor_gen = gen.flow_from_directory(POS_DIR, 
                                                      target_size=(150, 150),
                                                     batch_size=batch_size)

        pos_gen = gen.flow_from_directory(POS_DIR, 
                                                      target_size=(150, 150),
                                                     batch_size=batch_size)

        neg_gen = gen.flow_from_directory(NEG_DIR, 
                                                      target_size=(150, 150),
                                                     batch_size=batch_size)
    
#         print("Anchor: {} , Neg: {}".format(anchor_label, neg_label))
        X1i = anchor_gen.next()
        X2i = pos_gen.next()
        X3i = neg_gen.next()
        
        yield [X1i[0], X2i[0], X3i[0]], X1i[1]

# %%
def get_triplets(x, y, sample_size):
    a = []
    p = []
    n = []
    
    num_classes = len(set(y))
    for _ in range(sample_size):
        num1, num2 = random.sample(set(y), 2)
        positive_pool = x[np.where(y == num1)[0]]
        negative_pool = x[np.where(y == num2)[0]]
        
        anchor, positive = random.sample(positive_pool, 2)
        negative = negative_pool[random.randint(0, len(negative_pool)-1)]
        
        a.append(anchor)
        p.append(positive)
        n.append(negative)
        
    return np.asarray(a), np.asarray(p), np.asarray(n)

# %%
sample_size = 100
t_a, t_p, t_n = get_triplets(images, labels, sample_size)

# %% [markdown]
# ## 6.2 triplet test

# %%
count_true = 0
for k in range(sample_size):
    anchor_encoding = item_to_encoding(t_a[k], base_network)
    pos_encoding = item_to_encoding(t_p[k], base_network)
    neg_encoding = item_to_encoding(t_n[k], base_network)

#     anchor_pos_dist = np.linalg.norm(anchor_encoding-pos_encoding)
#     anchor_neg_dist = np.linalg.norm(anchor_encoding-neg_encoding)

    pos_dist = tf.reduce_sum(tf.square(tf.subtract(anchor_encoding,pos_encoding)),1)
    neg_dist = tf.reduce_sum(tf.square(tf.subtract(anchor_encoding,neg_encoding)),1)
    
    # -ln(-x/N+1)
    anchor_pos_dist = -tf.math.log(-tf.divide((pos_dist),128)+1+1e-8)
    anchor_neg_dist = -tf.math.log(-tf.divide((128-neg_dist),128)+1+1e-8)

    cond = anchor_pos_dist < anchor_neg_dist
    
    if cond: count_true += 1
        
    else: 
        print('---------- wrong embedding : index %d -----------'%k)
        plt.imshow(np.hstack([t_a[k, :, :], t_p[k, :, :], t_n[k, :, :]]))
        plt.show()
        
print("true: {} false: {}".format(count_true, sample_size-count_true))
print("Accuracy: {}".format(count_true / sample_size))

# %% [markdown]
# ## 6.3 Anchor test

# %%
#일부만 테스트 + 이미지 출력
thresh = 0.1

test_size = 100

anchor = images[100]
anchor_encoding = item_to_encoding(anchor, base_network)

plt.figure(figsize=(300, 300))

cc = 3
rr = int(len(images[:test_size]) / cc)+1

plt.subplot( rr ,cc, 1)
plt.imshow(anchor, cmap = 'gray')
plt.xlabel("Anchor({})".format(labels[0]), fontsize=80)

correct_count = 0

for k in range(len(images[:test_size])):        
    i = images[k]          
    plt.subplot( rr ,cc, k+2)   # 몇 칼럼 몇 로우로 그래프 그릴지
    plt.imshow(i, cmap = 'gray')
    item_encoding = item_to_encoding(i, base_network)
    
    dist = tf.reduce_sum(tf.square(tf.subtract(anchor_encoding, item_encoding)),1)
    dist = -tf.math.log(-tf.divide((dist),128)+1+1e-8)
    dist = dist.numpy()[0]
    
    similar = True if dist < thresh else False
    SIM = "SIMILAR" if similar else "NOT SIMILAR"
    cond = labels[0] == labels[k]
    
    if (similar and cond) or (not similar and not cond ):
        c = "blue"
        correct_count += 1
    else: c = "red"
    
    plt.xlabel("{} true label: {} distance from anchor: {:.2f}".format(SIM, labels[k], dist),  color = c, fontsize=80)
    
print("true: {}, false: {}".format(correct_count, test_size-correct_count))
print("Accuracy: {}".format(correct_count / test_size))

# %%
#전체 테스트
#이미지 많이 출력하면 커널 죽어서 이미지 출력은 주석처리
thresh = 0.1

anchor = images[0]
anchor_encoding = item_to_encoding(anchor, base_network)

# plt.figure(figsize=(150, 150))

# cc = 3
# rr = int(len(images[:50]) / cc)+1

# plt.subplot( rr ,cc, 1)
# plt.imshow(anchor, cmap = 'gray')
# plt.xlabel("Anchor({})".format(labels[0]), fontsize=80)

correct_count = 0

for k in range(len(images[:200])):        
    i = images[k]          
#     plt.subplot( rr ,cc, k+2)   # 몇 칼럼 몇 로우로 그래프 그릴지
#     plt.imshow(i, cmap = 'gray')
    item_encoding = item_to_encoding(i, base_network)
    
    dist = tf.reduce_sum(tf.square(tf.subtract(anchor_encoding, item_encoding)),1)
    dist = -tf.math.log(-tf.divide((dist),128)+1+1e-8)
    dist = dist.numpy()[0]
    
    similar = True if dist < thresh else False
    SIM = "SIMILAR" if similar else "NOT SIMILAR"
    cond = labels[0] == labels[k]
    
    if (similar and cond) or (not similar and not cond ):
        c = "blue"
        correct_count += 1
    else: c = "red"
    
#     plt.xlabel("{} true label: {} distance from anchor: {:.2f}".format(SIM, labels[k], dist),  color = c, fontsize=80)
    
print("true: {}, false: {}".format(correct_count, 200-correct_count))
print("Accuracy: {}".format(correct_count / 200))

# %% [markdown]
# ## 6.3 Anchor-all test

# %%
thresh = 0.1

anchor = images[0]
anchor_encoding = item_to_encoding(anchor, loaded_base_network)

# plt.figure(figsize=(150, 150))

# cc = 3
# rr = int(len(images[:50]) / cc)+1

# plt.subplot( rr ,cc, 1)
# plt.imshow(anchor, cmap = 'gray')
# plt.xlabel("Anchor({})".format(labels[0]), fontsize=80)

correct_count = 0

for k in range(len(images[:200])):        
    i = images[k]          
#     plt.subplot( rr ,cc, k+2)   # 몇 칼럼 몇 로우로 그래프 그릴지
#     plt.imshow(i, cmap = 'gray')
    item_encoding = item_to_encoding(i, loaded_base_network)
    
    dist = tf.reduce_sum(tf.square(tf.subtract(anchor_encoding, item_encoding)),1)
    dist = -tf.math.log(-tf.divide((dist),128)+1+1e-8)
    dist = dist.numpy()[0]
    
    similar = True if dist < thresh else False
    SIM = "SIMILAR" if similar else "NOT SIMILAR"
    cond = labels[0] == labels[k]
    
    if (similar and cond) or (not similar and not cond ):
        c = "blue"
        correct_count += 1
    else: c = "red"
    
#     plt.xlabel("{} true label: {} distance from anchor: {:.2f}".format(SIM, labels[k], dist),  color = c, fontsize=80)
    
print("true: {}, false: {}".format(correct_count, 200-correct_count))
print("Accuracy: {}".format(correct_count / 200))

# %% [markdown]
# ## 6.4 Anchor-Positive test

# %%
thresh = 0.1

anchor_index = 0     #테스트할 anchor의 인덱스

anchor = images[anchor_index]
anchor_label = labels[anchor_index]
anchor_encoding = item_to_encoding(anchor, base_network)

positive_images = images[np.where(labels == anchor_label)]     #anchor와 라벨이 같은 positive 이미지들
num_positive = len(positive_images)     #positive 이미지 개수

plt.figure(figsize=(150, 150))

cc = 3
rr = int(num_positive / cc)+1

plt.subplot( rr ,cc, 1)
plt.imshow(anchor, cmap = 'gray')
plt.xlabel("Anchor", fontsize=80)

correct_count = 0

for k in range(num_positive):        
    i = positive_images[k]          
    plt.subplot( rr ,cc, k+2)   # 몇 칼럼 몇 로우에 이미지 표시할지
    plt.imshow(i)
    item_encoding = item_to_encoding(i, base_network)
    
    dist = tf.reduce_sum(tf.square(tf.subtract(anchor_encoding, item_encoding)),1)
    dist = -tf.math.log(-tf.divide((dist),128)+1+1e-8)
    dist = dist.numpy()[0]
    
    similar = True if dist < thresh else False
    SIM = "SIMILAR" if similar else "NOT SIMILAR"
    
    if similar:
        c = "blue"
        correct_count += 1
    else: c = "red"
    
#     plt.xlabel("{} true label: {} distance from anchor: {:.2f}".format(SIM, labels[k], dist),  color = c, fontsize=80)
    
print("true: {}, false: {}".format(correct_count, num_positive-correct_count))
print("Accuracy: {}".format(correct_count / num_positive))

# %%
def sub_dir(o_dir, n_dir):
    """
    Arguments:
    - o_dir: old directory. 뎁스 바꿔주고 싶은 이미지 폴더(루트)
    e.g. '../../img/mmfashion'
    
    -n_dir: new directory. 새로운 폴더명. 아무거나 상관없음
    e.g. '../../img/mmfashion_flow'
    
    Return:
    없음
    
    """
    dirlist=os.listdir(o_dir)
    for i in dirlist:
        if not os.path.exists(n_dir):
            os.mkdir(n_dir)
        if not os.path.exists(n_dir+'/'+i):
            os.mkdir(n_dir+'/'+i)
        shutil.move(o_dir+"/"+i,n_dir+'/'+i)
        
sub_dir( '../masked_moved',  '../masked_moved2')
